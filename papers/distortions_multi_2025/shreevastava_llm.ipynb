# %%
import os, sys
import datetime as dt
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
from langchain_ollama.chat_models import ChatOllama

if 'api' in sys.modules:
    del sys.modules['api']
if 'plot' in sys.modules:
    del sys.modules['plot']
if 'util' in sys.modules:
    del sys.modules['util']
if 'recognition_evaluators' in sys.modules:
    del sys.modules['recognition_evaluators']

from recognition_evaluators import evaluate_tm_df, our_evaluator_true, our_evaluator_false, our_evaluator_top1, language_metrics
from util import dictcount
from api import TextMetrics
from plot import plot_bar_from_list_minmax

grand_t0 = dt.datetime.now()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\anton\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Experiment with multi-class cognitive distorion detection

# %%
texts = [
    ("I think he thinks about me.", "Mind Reading"),
    ("It always happens every time over and over again", "Overgeneralization"),
    ("This is enourmously huge and terrific.", "Magnification"),
    ("I know it will be that way and I forecast it.", "Furtune-telling"),
    ("He is stupid, lazy and ignorant narciss.", "Labeling"),
    ("I am guilty and it is my failure.", "Personalization"),
    ("I am either excited and amazed or abused and upset.", "Emotional reasoning"), 
    ("I ruined the whole recital because of that one mistake.", "Mental filter"),
    ("I must do it, I should have that.", "Should statement"),
    ("A single mistake ruins the entire life. Either you love me or you hate me.", "All-or-nothing thinking")
]
dists = set([x[1] for x in texts])
dists
# Out:
# {'All-or-nothing thinking',
#  'Emotional reasoning',
#  'Furtune-telling',
#  'Labeling',
#  'Magnification',
#  'Mental filter',
#  'Mind Reading',
#  'Overgeneralization',
#  'Personalization',
#  'Should statement'}

# %%
llm_llama32 = ChatOllama(model="llama3.2", base_url="http://localhost:11434", temperature=0.0)  # Explicitly set base_url
llm_qwen2 = ChatOllama(model="qwen2", base_url="http://localhost:11434", temperature=0.0)  # Explicitly set base_url
llm_qwen25_7 = ChatOllama(model="qwen2.5:7b", base_url="http://localhost:11434", temperature=0.0)

# %%
def evaluate_specific_model(model,text,dists,debug=False):
    query = f'You are professional psycho-therapist experienced in cognitive-behavioral therapy. '\
f'You can label texts witn none or some of cognitive distortoions, represented by the following labels: {str(dists)}. '\
f'When labeling, return only JSON array in square brackets of strings in double quotes representing the labels. '\
f'Label this text for presense or absence of any cognitive distortions fom given list: "{text}"'
    if debug:
        print(query)
    rep = model.invoke(query).content
    return rep

# %%
print(evaluate_specific_model(llm_llama32,"I think he thinks about me.",dists,True))
print(evaluate_specific_model(llm_qwen2,"I think he thinks about me.",dists,True))
print(evaluate_specific_model(llm_qwen25_7,"I think he thinks about me.",dists,True))
# Out:
# You are professional psycho-therapist experienced in cognitive-behavioral therapy. You can label texts witn none or some of cognitive distortoions, represented by the following labels: {'Overgeneralization', 'Should statement', 'Labeling', 'All-or-nothing thinking', 'Magnification', 'Mind Reading', 'Emotional reasoning', 'Furtune-telling', 'Personalization', 'Mental filter'}. When labeling, return only JSON array in square brackets of strings in double quotes representing the labels. Label this text for presense or absence of any cognitive distortions fom given list: "I think he thinks about me."
# ["Mind Reading"]
#
# This statement suggests that the speaker is inferring their partner's thoughts without direct evidence, which is a classic example of mind reading.
# ...

# %%
for t in texts:
    print(f"{t[1]}: {t[0]}")
    rep = evaluate_specific_model(llm_llama32,t,dists,False)
    print(rep)
    rep_list = []
    for metric in dists:
        if metric in rep:
            rep_list.append(metric)
    print({value: 1.0 for index, value in enumerate(rep_list)})
    print()
# Out:
# Mind Reading: I think he thinks about me.
# ["Mind Reading"]
# {'Mind Reading': 1.0}
#
# Overgeneralization: It always happens every time over and over again
# ["Overgeneralization"]
# {'Overgeneralization': 1.0}
#
# Magnification: This is enourmously huge and terrific.
# ["Magnification"]
# {'Magnification': 1.0}
#
# Furtune-telling: I know it will be that way and I forecast it.
# [{'Overgeneralization': false, 'Should statement': false, 'Labeling': false, 'All-or-nothing thinking': false, 'Magnification': false, 'Mind Reading': false, 'Emotional reasoning': false, 'Fortune-telling': true, 'Personalization': false, 'Mental filter': false}]
# {'Overgeneralization': 1.0, 'Should statement': 1.0, 'Labeling': 1.0, 'All-or-nothing thinking': 1.0, 'Magnification': 1.0, 'Mind Reading': 1.0, 'Emotional reasoning': 1.0, 'Personalization': 1.0, 'Mental filter': 1.0}
#
# Labeling: He is stupid, lazy and ignorant narciss.
# ["Labeling"]
# {'Labeling': 1.0}
#
# ...

# %%
# Dataset: Multiple Distorions (sagarikashreevastava)
# Paper: https://aclanthology.org/2021.clpsych-1.17/
# Data: https://www.kaggle.com/datasets/sagarikashreevastava/cognitive-distortion-detetction-dataset

# !pip install kagglehub
import kagglehub
multiclass_dataset_path = kagglehub.dataset_download("sagarikashreevastava/cognitive-distortion-detetction-dataset")
print("Path to dataset files:", multiclass_dataset_path)
multiclass_dataset_file_path = multiclass_dataset_path + "/Annotated_data.csv"
# Out:
# ...
# Path to dataset files: C:\Users\anton\.cache\kagglehub\datasets\sagarikashreevastava\cognitive-distortion-detetction-dataset\versions\1

# %% [markdown]
# ## Explore accuracy for primary distortion in Multi-class dataset

# %%
df = pd.read_csv(multiclass_dataset_file_path) 
df = df.drop('Id_Number', axis=1) # delete columnb with id 
df
# Out:
#                                        Patient Question  \
# 0     Hello, I have a beautiful,smart,outgoing and a...
# 1     Since I was about 16 years old I’ve had these ...
# 2      So I’ve been dating on and off this guy for a...
# 3     My parents got divorced in 2004. My mother has...
# 4     I don’t really know how to explain the situati...
# ...                                                 ...
# 2525  I’m a 21 year old female. I spent most of my l...
# 2526  I am 21 female and have not had any friends fo...
# 2527  From the U.S.: My brother is 19 years old and ...
# 2528  From the U.S.: I am a 21 year old woman who ha...
# 2529  I recently moved out on my ex-roommate because...
#
#                                          Distorted part Dominant Distortion  \
# 0     The voice are always fimilar (someone she know...     Personalization
# 1     I feel trapped inside my disgusting self and l...            Labeling
# ...

# %%
held_fraction = 5 # withheld test set
held_df  = df[df.index % held_fraction == 0].reset_index(drop=True)
held_df
# Out:
#                                       Patient Question  \
# 0    Hello, I have a beautiful,smart,outgoing and a...
# 1    Hello. I have been friend with a guy since gra...
# 2    My husband and I have been married for over a ...
# 3    I started going to therapy in December, after ...
# 4    I have always suffered from performance anxiet...
# ..                                                 ...
# 501  Hi there, my mother was diagnosed with Bipolar...
# 502  From the U.S.: I’ve been diagnosed with OCD si...
# 503  From the U.S.: I have had anxiety almost all o...
# 504  Hi, for about 3 years now I have been feeling ...
# 505  I’m a 21 year old female. I spent most of my l...
#
#                                         Distorted part  Dominant Distortion  \
# 0    The voice are always fimilar (someone she know...      Personalization
# 1                                                  NaN        No Distortion
# ...

# %%
all_dists = {}
for _, row in df.iterrows():
    # Text definition: first, check the 2nd column; if NaN, take the text from the 1st column.
    text = row.iloc[1] if pd.notna(row.iloc[1]) else row.iloc[0]
    primary_distortion = row.iloc[2]  # The main cognitive distortion from the 3rd column
    secondary_distortion = row.iloc[3] if pd.notna(row.iloc[3]) else None  # The secondary distortion from the 4th column, if it exists
    dictcount(all_dists,primary_distortion)
    if not secondary_distortion is None:
        dictcount(all_dists,secondary_distortion)
print(all_dists)
del all_dists['No Distortion']
all_dists
# Out:
# {'Personalization': 202, 'Labeling': 203, 'Emotional Reasoning': 169, 'No Distortion': 933, 'Fortune-telling': 210, 'Magnification': 245, 'Mind Reading': 295, 'All-or-nothing thinking': 126, 'Overgeneralization': 277, 'Mental filter': 151, 'Should statements': 135}
# {'Personalization': 202,
#  'Labeling': 203,
#  'Emotional Reasoning': 169,
#  'Fortune-telling': 210,
#  'Magnification': 245,
#  'Mind Reading': 295,
#  'All-or-nothing thinking': 126,
#  'Overgeneralization': 277,
#  'Mental filter': 151,
#  'Should statements': 135}

# %%
split_shifts = [0,1,2]
validation_fraction = 5
labels = sorted(all_dists)
labels
# Out:
# ['All-or-nothing thinking',
#  'Emotional Reasoning',
#  'Fortune-telling',
#  'Labeling',
#  'Magnification',
#  'Mental filter',
#  'Mind Reading',
#  'Overgeneralization',
#  'Personalization',
#  'Should statements']

# %%
def llm_evaluator_top1(all_metrics,model,text,threshold,top=1):
    rep = evaluate_specific_model(model,text,dists=all_metrics,debug=False)
    #print(text)
    #print(rep)
    rep_list = []
    for metric in all_metrics:
        if metric in rep:
            rep_list.append(metric)
    dic = {value: 1.0 for index, value in enumerate(rep_list[:top])}
    #print(dic)
    return dic

def llm_evaluator_top10(all_metrics,model,text,threshold,top=10):
    rep = evaluate_specific_model(model,text,dists=all_metrics,debug=False)
    #print(text)
    #print(rep)
    rep_list = []
    for metric in all_metrics:
        if metric in rep:
            rep_list.append(metric)
    dic = {value: 1.0 for index, value in enumerate(rep_list[:top])}
    #print(dic)
    return dic

# %%
all_eval_results = {}

# %%
eval_results = []
for split_shift in split_shifts:
    test_df  = df[(df.index + split_shift) % validation_fraction == 0]
    eval_result = evaluate_tm_df(test_df,None,our_evaluator_true,None,all_metrics=all_dists,encode_spaces=False,debug=False)
    eval_results.append(eval_result)

for eval_result in eval_results:
    print(eval_result[2]) # F1

all_eval_results['Const(True)'] = eval_results
# Out:
# {'Personalization': 0.16, 'Labeling': 0.14990859232175505, 'Emotional Reasoning': 0.12939001848428835, 'Fortune-telling': 0.17328519855595667, 'Magnification': 0.18962432915921287, 'Mind Reading': 0.16998191681735988, 'All-or-nothing thinking': 0.09416195856873823, 'Overgeneralization': 0.20884955752212392, 'Mental filter': 0.11194029850746268, 'Should statements': 0.10131332082551595}
# {'Personalization': 0.15328467153284672, 'Labeling': 0.17657657657657655, 'Emotional Reasoning': 0.09774436090225565, 'Fortune-telling': 0.16666666666666669, 'Magnification': 0.16998191681735988, 'Mind Reading': 0.21516754850088185, 'All-or-nothing thinking': 0.11895910780669143, 'Overgeneralization': 0.199288256227758, 'Mental filter': 0.10486891385767791, 'Should statements': 0.08333333333333333}
# ...

# %%
eval_results = []
for split_shift in split_shifts:
    test_df  = df[(df.index + split_shift) % validation_fraction == 0]
    eval_result = evaluate_tm_df(test_df,None,our_evaluator_false,None,all_metrics=all_dists,encode_spaces=False,debug=False)
    eval_results.append(eval_result)

for eval_result in eval_results:
    print(eval_result[2]) # F1

all_eval_results['Const(False)'] = eval_results
# Out:
# {'Personalization': 0, 'Labeling': 0, 'Emotional Reasoning': 0, 'Fortune-telling': 0, 'Magnification': 0, 'Mind Reading': 0, 'All-or-nothing thinking': 0, 'Overgeneralization': 0, 'Mental filter': 0, 'Should statements': 0}
# {'Personalization': 0, 'Labeling': 0, 'Emotional Reasoning': 0, 'Fortune-telling': 0, 'Magnification': 0, 'Mind Reading': 0, 'All-or-nothing thinking': 0, 'Overgeneralization': 0, 'Mental filter': 0, 'Should statements': 0}
# {'Personalization': 0, 'Labeling': 0, 'Emotional Reasoning': 0, 'Fortune-telling': 0, 'Magnification': 0, 'Mind Reading': 0, 'All-or-nothing thinking': 0, 'Overgeneralization': 0, 'Mental filter': 0, 'Should statements': 0}

# %%
all_metricsmap = {'All-or-nothing_thinking':'dichotomous-reasoning',
              'Fortune-telling':'fortune-telling',
              'Mental_filter':'mental-filtering',
              'Overgeneralization':'overgeneralizing',
              'Labeling':'labeling',
              'Mind_Reading':'mindreading',
              'Personalization':'personalizing',
              'Emotional_Reasoning':'emotional-reasoning',
              'Magnification':'magnification',
              'Should_statements':'should-statement'}

def language_metrics(lang,metrics_list,path):
    metrics = {}
    for m in metrics_list:
        metrics[m] = path + lang + '/' + metrics_list[m] + '.txt'
    return metrics

tm_base = TextMetrics(language_metrics('',all_metricsmap,path='../../data/models/distortions/ours')
                  ,encoding="utf-8",metric_logarithmic=True,debug=False)

eval_results = []
for split_shift in split_shifts:
    #test_df  = df[(df.index + split_shift) % 1 == 0]
    test_df  = df[(df.index + split_shift) % validation_fraction == 0]
    #eval_result = evaluate_tm_df(test_df,tm_base,our_evaluator_top1,0.3,all_metrics=all_dists,encode_spaces=False,debug=False) # WRONG SPACES!!! 
    eval_result = evaluate_tm_df(test_df,tm_base,our_evaluator_top1,0.3,all_metrics=list(all_metricsmap),encode_spaces=True,debug=False)
    eval_results.append(eval_result)

#decode spaces
new_eval_results = []
for eval_result in eval_results:
    new_list = []
    for i in [0,1,2,3]:
        dists = {}
        old = eval_result[i]
        for d in old:
            dists[d.replace('_',' ')] = old[d]
        new_list.append(dists)
    new_eval_results.append(tuple(new_list))
eval_results = new_eval_results

all_eval_results['arinicheva25'] = eval_results

for eval_result in eval_results:
    print(eval_result[2]) # F1

print(dt,sum([sum(eval_result[2].values())/len(eval_result[2].values()) for eval_result in eval_results])/3)
# Out:
# {'All-or-nothing thinking': 0.15384615384615383, 'Fortune-telling': 0, 'Mental filter': 0, 'Overgeneralization': 0.23529411764705882, 'Labeling': 0.14814814814814817, 'Mind Reading': 0, 'Personalization': 0.2857142857142857, 'Emotional Reasoning': 0.6666666666666666, 'Magnification': 0, 'Should statements': 0.47058823529411764}
# {'All-or-nothing thinking': 0.20930232558139533, 'Fortune-telling': 0, 'Mental filter': 0, 'Overgeneralization': 0.47619047619047616, 'Labeling': 0.5185185185185185, 'Mind Reading': 0.7272727272727273, 'Personalization': 0.4186046511627907, 'Emotional Reasoning': 0.5, 'Magnification': 0.2857142857142857, 'Should statements': 0.2}
# {'All-or-nothing thinking': 0.11235955056179774, 'Fortune-telling': 0, 'Mental filter': 0, 'Overgeneralization': 0.4848484848484849, 'Labeling': 0.4444444444444445, 'Mind Reading': 0.6666666666666666, 'Personalization': 0.48484848484848486, 'Emotional Reasoning': 0.33333333333333337, 'Magnification': 0, 'Should statements': 0.56}
# ...

# %%
eval_results = []
for split_shift in split_shifts:
    test_df  = df[(df.index + split_shift) % validation_fraction == 0]
    eval_result = evaluate_tm_df(test_df,llm_llama32,llm_evaluator_top1,None,all_metrics=all_dists,encode_spaces=False,debug=False)
    eval_results.append(eval_result)

for eval_result in eval_results:
    print(eval_result[2]) # F1

all_eval_results['LLAMA 3.2'] = eval_results
# Out:
# {'Personalization': 0.1550387596899225, 'Labeling': 0.12121212121212122, 'Emotional Reasoning': 0.1904761904761905, 'Fortune-telling': 0, 'Magnification': 0, 'Mind Reading': 0, 'All-or-nothing thinking': 0.07999999999999999, 'Overgeneralization': 0, 'Mental filter': 0, 'Should statements': 0.5}
# {'Personalization': 0.14814814814814814, 'Labeling': 0.3846153846153846, 'Emotional Reasoning': 0.1724137931034483, 'Fortune-telling': 0, 'Magnification': 0, 'Mind Reading': 0, 'All-or-nothing thinking': 0.12244897959183672, 'Overgeneralization': 0, 'Mental filter': 0, 'Should statements': 0.25}
# {'Personalization': 0.15384615384615385, 'Labeling': 0.2222222222222222, 'Emotional Reasoning': 0.2830188679245283, 'Fortune-telling': 0, 'Magnification': 0, 'Mind Reading': 0, 'All-or-nothing thinking': 0.22580645161290322, 'Overgeneralization': 0, 'Mental filter': 0, 'Should statements': 0.7272727272727273}

# %%
eval_results = []
for split_shift in split_shifts:
    test_df  = df[(df.index + split_shift) % validation_fraction == 0]
    eval_result = evaluate_tm_df(test_df,llm_qwen2,llm_evaluator_top1,None,all_metrics=all_dists,encode_spaces=False,debug=False)
    eval_results.append(eval_result)

for eval_result in eval_results:
    print(eval_result[2]) # F1

all_eval_results['QWEN 2'] = eval_results
# Out:
# {'Personalization': 0.4615384615384615, 'Labeling': 0.19101123595505617, 'Emotional Reasoning': 0.25, 'Fortune-telling': 0.4473684210526315, 'Magnification': 0, 'Mind Reading': 0, 'All-or-nothing thinking': 0, 'Overgeneralization': 0.15873015873015872, 'Mental filter': 0.5, 'Should statements': 1.0}
# {'Personalization': 0.4444444444444445, 'Labeling': 0.21782178217821782, 'Emotional Reasoning': 0.1875, 'Fortune-telling': 0.4, 'Magnification': 0, 'Mind Reading': 0, 'All-or-nothing thinking': 0, 'Overgeneralization': 0.21538461538461542, 'Mental filter': 0, 'Should statements': 0}
# {'Personalization': 0.8, 'Labeling': 0.15789473684210528, 'Emotional Reasoning': 0.25, 'Fortune-telling': 0.2424242424242424, 'Magnification': 0, 'Mind Reading': 1.0, 'All-or-nothing thinking': 0.6666666666666666, 'Overgeneralization': 0.1875, 'Mental filter': 0, 'Should statements': 1.0}

# %%
eval_results = []
for split_shift in split_shifts:
    test_df  = df[(df.index + split_shift) % validation_fraction == 0]
    eval_result = evaluate_tm_df(test_df,llm_qwen25_7,llm_evaluator_top1,None,all_metrics=all_dists,encode_spaces=False,debug=False)
    eval_results.append(eval_result)

for eval_result in eval_results:
    print(eval_result[2]) # F1

all_eval_results['QWEN 2.5:7B'] = eval_results
# Out:
# {'Personalization': 0.45161290322580644, 'Labeling': 0.2097378277153558, 'Emotional Reasoning': 0.2666666666666667, 'Fortune-telling': 0.5542168674698795, 'Magnification': 0, 'Mind Reading': 0.8571428571428571, 'All-or-nothing thinking': 0.25, 'Overgeneralization': 0.3508771929824561, 'Mental filter': 0.2222222222222222, 'Should statements': 0.6}
# {'Personalization': 0.6206896551724138, 'Labeling': 0.26480836236933797, 'Emotional Reasoning': 0.25806451612903225, 'Fortune-telling': 0.6341463414634146, 'Magnification': 0, 'Mind Reading': 0.4444444444444445, 'All-or-nothing thinking': 0.19999999999999998, 'Overgeneralization': 0.2444444444444444, 'Mental filter': 0, 'Should statements': 0.4444444444444445}
# ...

# %%
all_metricsmap = {value: value.replace(' ','_') for index, value in enumerate(all_dists)}

def language_metrics(lang,metrics_list,path):
    metrics = {}
    for m in metrics_list:
        metrics[m] = path + lang + '/' + metrics_list[m] + '.txt'
    return metrics

eval_results = []
for split_shift in split_shifts:
    test_df  = df[(df.index + split_shift) % validation_fraction == 0]
    tm_new = TextMetrics(language_metrics('',all_metricsmap,path=f'../../data/models/distortions/shreevastava2021/multiclass-{split_shift+1}-0'),
                         encoding="utf-8",metric_logarithmic=True,debug=False)
    eval_result = evaluate_tm_df(test_df,tm_new,our_evaluator_top1,0.5,all_metrics=all_dists,encode_spaces=False,debug=False)
    eval_results.append(eval_result)

for eval_result in eval_results:
    print(eval_result[2]) # F1

all_eval_results['ours26'] = eval_results
# Out:
# {'Personalization': 0.2535211267605634, 'Labeling': 0.24000000000000002, 'Emotional Reasoning': 0.33333333333333337, 'Fortune-telling': 0.5333333333333333, 'Magnification': 0.3023255813953488, 'Mind Reading': 0.2857142857142857, 'All-or-nothing thinking': 0.2857142857142857, 'Overgeneralization': 0.37254901960784315, 'Mental filter': 0.3571428571428571, 'Should statements': 0.3636363636363636}
# {'Personalization': 0.20689655172413793, 'Labeling': 0.4210526315789474, 'Emotional Reasoning': 0.16666666666666669, 'Fortune-telling': 0.47058823529411764, 'Magnification': 0.1758241758241758, 'Mind Reading': 0.2751322751322751, 'All-or-nothing thinking': 0.5, 'Overgeneralization': 0.25742574257425743, 'Mental filter': 0, 'Should statements': 0.25}
# ...

# %%
all_metricsmap = {value: value.replace(' ','_') for index, value in enumerate(all_dists)}

def language_metrics(lang,metrics_list,path):
    metrics = {}
    for m in metrics_list:
        metrics[m] = path + lang + '/' + metrics_list[m] + '.txt'
    return metrics

eval_results = []
for split_shift in split_shifts:
    test_df  = df[(df.index + split_shift) % validation_fraction == 0]
    tm_new = TextMetrics(language_metrics('',all_metricsmap,path=f'../../data/models/distortions/shreevastava2021/multiclass-{split_shift+1}-0'),
                         encoding="utf-8",metric_logarithmic=True,weighted=True,debug=False)
    eval_result = evaluate_tm_df(test_df,tm_new,our_evaluator_top1,0.5,all_metrics=all_dists,encode_spaces=False,debug=False)
    eval_results.append(eval_result)

for eval_result in eval_results:
    print(eval_result[2]) # F1

all_eval_results['ours26-weighted'] = eval_results
# Out:
# {'Personalization': 0.3846153846153846, 'Labeling': 0.3, 'Emotional Reasoning': 0.5333333333333333, 'Fortune-telling': 0.7027027027027027, 'Magnification': 0.37037037037037035, 'Mind Reading': 0.32894736842105265, 'All-or-nothing thinking': 0.5, 'Overgeneralization': 0.4651162790697674, 'Mental filter': 0.2608695652173913, 'Should statements': 0.5555555555555556}
# {'Personalization': 0.36363636363636365, 'Labeling': 0.4761904761904762, 'Emotional Reasoning': 0.11764705882352941, 'Fortune-telling': 0.5806451612903225, 'Magnification': 0.3461538461538462, 'Mind Reading': 0.5321100917431193, 'All-or-nothing thinking': 0.5, 'Overgeneralization': 0.46808510638297873, 'Mental filter': 0.2222222222222222, 'Should statements': 0.7272727272727273}
# ...

# %%
all_metricsmap = {value: value.replace(' ','_') for index, value in enumerate(all_dists)}

def language_metrics(lang,metrics_list,path):
    metrics = {}
    for m in metrics_list:
        metrics[m] = path + lang + '/' + metrics_list[m] + '.txt'
    return metrics

eval_results = []
for split_shift in split_shifts:
    test_df  = held_df
    model_path = f'../../data/models/distortions/shreevastava2021-t/multiclass-{split_shift+1}-W-0'
    print(model_path)
    tm_new = TextMetrics(language_metrics('',all_metricsmap,path=model_path),
                         encoding="utf-8",metric_logarithmic=True,weighted=True,debug=False)
    eval_result = evaluate_tm_df(test_df,tm_new,our_evaluator_top1,0.6,all_metrics=all_dists,encode_spaces=False,debug=False)
    eval_results.append(eval_result)

for eval_result in eval_results:
    print(eval_result[2]) # F1

all_eval_results['ours26-weighted-t'] = eval_results
# Out:
# ../../data/models/distortions/shreevastava2021-t/multiclass-1-W-0
# ../../data/models/distortions/shreevastava2021-t/multiclass-2-W-0
# ../../data/models/distortions/shreevastava2021-t/multiclass-3-W-0
# {'Personalization': 0.5714285714285714, 'Labeling': 0.22222222222222224, 'Emotional Reasoning': 0.5, 'Fortune-telling': 0.45714285714285713, 'Magnification': 0.3076923076923077, 'Mind Reading': 0.38805970149253727, 'All-or-nothing thinking': 0, 'Overgeneralization': 0.4166666666666667, 'Mental filter': 0, 'Should statements': 0.5}
# {'Personalization': 0.3529411764705882, 'Labeling': 0.3333333333333333, 'Emotional Reasoning': 0.5454545454545454, 'Fortune-telling': 0.6428571428571429, 'Magnification': 0.3125, 'Mind Reading': 0.43478260869565216, 'All-or-nothing thinking': 0, 'Overgeneralization': 0.4545454545454546, 'Mental filter': 0.25, 'Should statements': 0.6153846153846154}
# ...

# %%
# Evaluate joint model (ours 2026) with splits, see shreevastava_clean.ipynb
all_metricsmap = {'All-or-nothing thinking':'dichotomous-reasoning',
              'Fortune-telling':'fortune-telling',
              'Mental filter':'mental-filtering',
              'Overgeneralization':'overgeneralizing',
              'Labeling':'labeling',
              'Mind Reading':'mindreading',
              'Personalization':'personalizing',
              'Emotional Reasoning':'emotional-reasoning',
              'Magnification':'magnification',
              'Should statements':'should-statement'}

def language_metrics(lang,metrics_filenames,path):
    metrics = {}
    for m in metrics_filenames:
        filename = metrics_filenames[m] if type(metrics_filenames) == dict else m
        metrics[m] = path + lang + '/' + filename + '.txt'
    return metrics

tm_26 = TextMetrics(language_metrics('',all_metricsmap,path='../../data/models/distortions/ours26')
                  ,encoding="utf-8",metric_logarithmic=True,debug=False)

eval_results = []
for split_shift in split_shifts:
    test_df  = df[(df.index + split_shift) % validation_fraction == 0]
    eval_result = evaluate_tm_df(test_df,tm_26,our_evaluator_top1,0.4,all_metrics=list(all_metricsmap),encode_spaces=False,debug=False)
    eval_results.append(eval_result)

for eval_result in eval_results:
    print(eval_result[2]) # F1

all_eval_results['ours26-cleaned'] = eval_results
# Out:
# {'All-or-nothing thinking': 0.2424242424242424, 'Fortune-telling': 0.631578947368421, 'Mental filter': 1.0, 'Overgeneralization': 0.5714285714285714, 'Labeling': 0.7, 'Mind Reading': 0.6666666666666666, 'Personalization': 0.3220338983050847, 'Emotional Reasoning': 0.46341463414634143, 'Magnification': 0.4444444444444444, 'Should statements': 0.41025641025641024}
# {'All-or-nothing thinking': 0.20689655172413793, 'Fortune-telling': 0.6956521739130436, 'Mental filter': 0.6666666666666666, 'Overgeneralization': 0.5789473684210527, 'Labeling': 0.7058823529411764, 'Mind Reading': 0.6428571428571429, 'Personalization': 0.27272727272727276, 'Emotional Reasoning': 0.2222222222222222, 'Magnification': 0.4615384615384615, 'Should statements': 0.32000000000000006}
# ...

# %%
def build_averages(results_3runs,labels):
    results = {}
    ranges = {}
    F1_macros = {}
    F1_minmaxes = {}
    for model in results_3runs:
        runs = results_3runs[model]
        #print(runs)
        #keys = set(runs[0][2].keys()).union(runs[1][2].keys(), runs[2][2].keys()) # F1
        model_averages = {}
        model_ranges = {}
        F1s = [sum(runs[run][2].values())/len(runs[run][2].values()) for run in [0,1,2]]
        F1_macros[model] = sum(F1s)/3
        F1_minmaxes[model] = (min(F1s),max(F1s))
        for key in labels:
            vals = [runs[0][2][key],runs[1][2][key],runs[2][2][key]]
            average = sum(vals)/3
            model_averages[key] = round(average,2)
            model_ranges[key] = (round(min(vals),2),round(max(vals),2))
        results[model] = [model_averages[key] for key in labels]
        ranges[model] = [model_ranges[key] for key in labels]
    return results, ranges, F1_macros, F1_minmaxes

labels = sorted(all_dists)
values, ranges, F1_macros, F1_minmaxes = build_averages(all_eval_results,labels)
del values['Const(False)']
del ranges['Const(False)']
del F1_macros['Const(False)']
del F1_minmaxes['Const(False)']
del values['ours26']
del ranges['ours26']
del F1_macros['ours26']
del F1_minmaxes['ours26']

for m in F1_macros:
    print(F1_macros[m],m)
print()
for m in F1_minmaxes:
    print(F1_minmaxes[m],m)
print()
for m in values:
    print(values[m],m)
print()
for m in ranges:
    print(ranges[m],m)
# Out:
# 0.14698599065756338 Const(True)
# 0.2794120518819945 arinicheva25
# 0.12455065999051956 LLAMA 3.2
# 0.29260949217388665 QWEN 2
# 0.3683103741323294 QWEN 2.5:7B
# 0.47346048064001295 ours26-weighted
# 0.376119776508086 ours26-weighted-t
# 0.5117402912242396 ours26-cleaned
#
# (0.14352531767424406, 0.14884551907624136) Const(True)
# (0.19602576073164307, 0.3335602984440194) arinicheva25
# (0.10467270713782342, 0.16121664228785348) LLAMA 3.2
# (0.14651508420072779, 0.43044856459330144) QWEN 2
# (0.31110422084675327, 0.4175792478077104) QWEN 2.5:7B
# (0.43339630537155854, 0.5468340806199246) ours26-weighted
# (0.3363212326645162, 0.39785820918560855) ours26-weighted-t
# (0.47733902130111777, 0.5452247815040183) ours26-cleaned
#
# [0.1, 0.11, 0.16, 0.15, 0.18, 0.11, 0.2, 0.2, 0.16, 0.1] Const(True)
# [0.16, 0.5, 0.0, 0.37, 0.1, 0.0, 0.46, 0.4, 0.4, 0.41] arinicheva25
# [0.14, 0.22, 0.0, 0.24, 0.0, 0.0, 0.0, 0.0, 0.15, 0.49] LLAMA 3.2
# ...

# %%
# Enter baseline F1 performance from the paper (Babacan, O˘guz, and Beyito˘glu 2025)
# https://dergipark.org.tr/tr/download/article-file/3865878, page 5, Table 2
base_babacan = {'Mind Reading': 0.6415,
'Should statements': 0.4615,
'All-or-nothing thinking': 0.2041,
'Overgeneralization': 0.4928,
'Mental filter': 0.0000,
'Magnification': 0.0000,
'Emotional Reasoning': 0.1250,
'Personalization': 0.3913,
'Fortune-telling': 0.4348,
'Labeling': 0.5000}

values['babacan25'] = [round(base_babacan[label],2) for label in labels]
ranges['babacan25'] = [(values['babacan25'],values['babacan25']) for label in labels]
F1_macros['babacan25'] = sum(values['babacan25'])/len(base_babacan)
F1_minmaxes['babacan25'] = (F1_macros['babacan25'],F1_macros['babacan25'])
print(F1_macros['babacan25'])
# Out:
# 0.323

# %% [markdown]
# ### Visualize all results (with "cleaned")

# %%
plt.rcParams["figure.figsize"] = (8,5)

x = np.arange(len(labels))  # the label locations
width = 0.12  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained',dpi=300)

for attribute, measurement in values.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    print(measurement, attribute)
    ax.bar_label(rects, padding=3, fontsize=7)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('F1')
ax.set_title('F1(Distortion,Model)')
ax.set_xticks(x + width, labels)
ax.legend(loc='upper left', ncols=2, fontsize=8)
ax.set_ylim(0, 0.8)
ax.tick_params(axis='x', rotation=20)
fig.set_dpi(300)

plt.show()
# Out:
# [0.1, 0.11, 0.16, 0.15, 0.18, 0.11, 0.2, 0.2, 0.16, 0.1] Const(True)
# [0.16, 0.5, 0.0, 0.37, 0.1, 0.0, 0.46, 0.4, 0.4, 0.41] arinicheva25
# [0.14, 0.22, 0.0, 0.24, 0.0, 0.0, 0.0, 0.0, 0.15, 0.49] LLAMA 3.2
# [0.22, 0.23, 0.36, 0.19, 0.0, 0.17, 0.33, 0.19, 0.57, 0.67] QWEN 2
# [0.28, 0.29, 0.48, 0.22, 0.0, 0.22, 0.77, 0.28, 0.59, 0.55] QWEN 2.5:7B
# [0.53, 0.44, 0.64, 0.37, 0.36, 0.34, 0.46, 0.44, 0.39, 0.76] ours26-weighted
# [0.17, 0.42, 0.61, 0.34, 0.35, 0.23, 0.41, 0.39, 0.39, 0.46] ours26-weighted-t
# [0.26, 0.32, 0.66, 0.74, 0.39, 0.78, 0.62, 0.59, 0.33, 0.42] ours26-cleaned
# [0.2, 0.12, 0.43, 0.5, 0.0, 0.0, 0.64, 0.49, 0.39, 0.46] babacan25

# %%
plt.rcParams["figure.figsize"] = (8,6)

x = np.arange(len(labels))  # the label locations
width = 0.12  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained',dpi=300)


for attribute, measurement in values.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    print(measurement, attribute)
    #ax.bar_label(rects, padding=3, fontsize=7)
    multiplier += 1

all_values = []
all_ranges = []
for m in values:
    for i in range(len(labels)):
        all_values.append(values[m][i])
        all_ranges.append(ranges[m][i])
for p,mm,v in zip(ax.patches,all_ranges,all_values):
            xe = p.get_x()  # get the bottom left x corner of the bar
            w = p.get_width()  # get width of bar
            h = p.get_height()  # get height of bar
            min_y = mm[0]
            max_y = mm[1]
            if min_y < max_y:
                plt.vlines(xe+w/2, min_y, max_y, color='k', linewidth=1)  # draw a vertical line
                plt.text(xe+w/2,max_y,str(round(v,2)),horizontalalignment='center',verticalalignment='bottom', fontsize=7)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('F1')
ax.set_title('F1(Distortion,Model)')
ax.set_xticks(x + width, labels)
ax.legend(loc='upper left', ncols=2, fontsize=8)
ax.set_ylim(0, 1.03)
ax.tick_params(axis='x', rotation=20)
fig.set_dpi(300)

plt.show()
# Out:
# [0.1, 0.11, 0.16, 0.15, 0.18, 0.11, 0.2, 0.2, 0.16, 0.1] Const(True)
# [0.16, 0.5, 0.0, 0.37, 0.1, 0.0, 0.46, 0.4, 0.4, 0.41] arinicheva25
# [0.14, 0.22, 0.0, 0.24, 0.0, 0.0, 0.0, 0.0, 0.15, 0.49] LLAMA 3.2
# [0.22, 0.23, 0.36, 0.19, 0.0, 0.17, 0.33, 0.19, 0.57, 0.67] QWEN 2
# [0.28, 0.29, 0.48, 0.22, 0.0, 0.22, 0.77, 0.28, 0.59, 0.55] QWEN 2.5:7B
# [0.53, 0.44, 0.64, 0.37, 0.36, 0.34, 0.46, 0.44, 0.39, 0.76] ours26-weighted
# [0.17, 0.42, 0.61, 0.34, 0.35, 0.23, 0.41, 0.39, 0.39, 0.46] ours26-weighted-t
# [0.26, 0.32, 0.66, 0.74, 0.39, 0.78, 0.62, 0.59, 0.33, 0.42] ours26-cleaned
# [0.2, 0.12, 0.43, 0.5, 0.0, 0.0, 0.64, 0.49, 0.39, 0.46] babacan25

# %%
avgs = []
minmaxs = []
models = list(values)
for m in values:
    #vals = values[m]
    #avg = round(sum(vals)/len(vals),2)
    #minv = min(vals)
    #maxv = max(vals)
    avg = F1_macros[m]
    minv, maxv = F1_minmaxes[m]
    avgs.append(avg)
    minmaxs.append((minv,maxv))
    print(avg, minv, maxv, m)

# https://dergipark.org.tr/tr/download/article-file/3865878, page 7, Table 5
# Do not include F1-macro from Babacan, because it includes "No Distortions" metric which is "binary" by its nature and brings unjustified high-score
# models.append('babacan25')
# avgs.append(0.4467)
# minmaxs.append((0.4467,0.4467))
# Out:
# 0.14698599065756338 0.14352531767424406 0.14884551907624136 Const(True)
# 0.2794120518819945 0.19602576073164307 0.3335602984440194 arinicheva25
# 0.12455065999051956 0.10467270713782342 0.16121664228785348 LLAMA 3.2
# 0.29260949217388665 0.14651508420072779 0.43044856459330144 QWEN 2
# 0.3683103741323294 0.31110422084675327 0.4175792478077104 QWEN 2.5:7B
# 0.47346048064001295 0.43339630537155854 0.5468340806199246 ours26-weighted
# 0.376119776508086 0.3363212326645162 0.39785820918560855 ours26-weighted-t
# 0.5117402912242396 0.47733902130111777 0.5452247815040183 ours26-cleaned
# 0.323 0.323 0.323 babacan25

# %%
def plot_bar_from_list_minmax(label,labels,value,values,title=None,fontsize=None,minmax=None,dpi=300,x_rotation=0):
    fig, ax = plt.subplots(figsize=(8, 4))
    plt.bar(labels, values)
    plt.title(f'{value}({label})' if title is None else title)
    plt.xlabel(label)
    plt.ylabel(value)
    if x_rotation != 0:
        ax.tick_params(axis='x', rotation=x_rotation)
    if not minmax is None:
        for p,mm,v in zip(ax.patches,minmax,values):
            x = p.get_x()  # get the bottom left x corner of the bar
            w = p.get_width()  # get width of bar
            h = p.get_height()  # get height of bar
            min_y = mm[0]
            max_y = mm[1]
            plt.vlines(x+w/2, min_y, max_y, color='k')  # draw a vertical line
            plt.text(x+w/2,max_y,str(round(v,2)),horizontalalignment='center',verticalalignment='bottom')
    fig.set_dpi(dpi)
    plt.show()


print(labels)
print(avgs)
print(minmaxs)
plot_bar_from_list_minmax('Model',models,'F1-average,macro',avgs,minmax=minmaxs,x_rotation=20)
# Out:
# ['All-or-nothing thinking', 'Emotional Reasoning', 'Fortune-telling', 'Labeling', 'Magnification', 'Mental filter', 'Mind Reading', 'Overgeneralization', 'Personalization', 'Should statements']
# [0.14698599065756338, 0.2794120518819945, 0.12455065999051956, 0.29260949217388665, 0.3683103741323294, 0.47346048064001295, 0.376119776508086, 0.5117402912242396, 0.323]
# [(0.14352531767424406, 0.14884551907624136), (0.19602576073164307, 0.3335602984440194), (0.10467270713782342, 0.16121664228785348), (0.14651508420072779, 0.43044856459330144), (0.31110422084675327, 0.4175792478077104), (0.43339630537155854, 0.5468340806199246), (0.3363212326645162, 0.39785820918560855), (0.47733902130111777, 0.5452247815040183), (0.323, 0.323)]

# %% [markdown]
# ### Visualize results excluding "cleaned" and "weighted"

# %%
for m in ['ours26-cleaned','ours26-weighted']:
    del values[m]
    del ranges[m]
    del F1_macros[m]
    del F1_minmaxes[m]

# %%
plt.rcParams["figure.figsize"] = (8,5)

x = np.arange(len(labels))  # the label locations
width = 0.12  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained',dpi=300)

for attribute, measurement in values.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    print(measurement, attribute)
    ax.bar_label(rects, padding=3, fontsize=7)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('F1')
ax.set_title('F1(Distortion,Model)')
ax.set_xticks(x + width, labels)
ax.legend(loc='upper left', ncols=2, fontsize=8)
ax.set_ylim(0, 0.8)
ax.tick_params(axis='x', rotation=20)
fig.set_dpi(300)

plt.show()
# Out:
# [0.1, 0.11, 0.16, 0.15, 0.18, 0.11, 0.2, 0.2, 0.16, 0.1] Const(True)
# [0.16, 0.5, 0.0, 0.37, 0.1, 0.0, 0.46, 0.4, 0.4, 0.41] arinicheva25
# [0.14, 0.22, 0.0, 0.24, 0.0, 0.0, 0.0, 0.0, 0.15, 0.49] LLAMA 3.2
# [0.22, 0.23, 0.36, 0.19, 0.0, 0.17, 0.33, 0.19, 0.57, 0.67] QWEN 2
# [0.28, 0.29, 0.48, 0.22, 0.0, 0.22, 0.77, 0.28, 0.59, 0.55] QWEN 2.5:7B
# [0.17, 0.42, 0.61, 0.34, 0.35, 0.23, 0.41, 0.39, 0.39, 0.46] ours26-weighted-t
# [0.2, 0.12, 0.43, 0.5, 0.0, 0.0, 0.64, 0.49, 0.39, 0.46] babacan25

# %%
plt.rcParams["figure.figsize"] = (8,6)

x = np.arange(len(labels))  # the label locations
width = 0.12  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained',dpi=300)


for attribute, measurement in values.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    print(measurement, attribute)
    #ax.bar_label(rects, padding=3, fontsize=7)
    multiplier += 1

all_values = []
all_ranges = []
for m in values:
    for i in range(len(labels)):
        all_values.append(values[m][i])
        all_ranges.append(ranges[m][i])
for p,mm,v in zip(ax.patches,all_ranges,all_values):
            xe = p.get_x()  # get the bottom left x corner of the bar
            w = p.get_width()  # get width of bar
            h = p.get_height()  # get height of bar
            min_y = mm[0]
            max_y = mm[1]
            if min_y < max_y:
                plt.vlines(xe+w/2, min_y, max_y, color='k', linewidth=1)  # draw a vertical line
                plt.text(xe+w/2,max_y,str(round(v,2)),horizontalalignment='center',verticalalignment='bottom', fontsize=7)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('F1')
ax.set_title('F1(Distortion,Model)')
ax.set_xticks(x + width, labels)
ax.legend(loc='upper left', ncols=2, fontsize=8)
ax.set_ylim(0, 1.03)
ax.tick_params(axis='x', rotation=20)
fig.set_dpi(300)

plt.show()
# Out:
# [0.1, 0.11, 0.16, 0.15, 0.18, 0.11, 0.2, 0.2, 0.16, 0.1] Const(True)
# [0.16, 0.5, 0.0, 0.37, 0.1, 0.0, 0.46, 0.4, 0.4, 0.41] arinicheva25
# [0.14, 0.22, 0.0, 0.24, 0.0, 0.0, 0.0, 0.0, 0.15, 0.49] LLAMA 3.2
# [0.22, 0.23, 0.36, 0.19, 0.0, 0.17, 0.33, 0.19, 0.57, 0.67] QWEN 2
# [0.28, 0.29, 0.48, 0.22, 0.0, 0.22, 0.77, 0.28, 0.59, 0.55] QWEN 2.5:7B
# [0.17, 0.42, 0.61, 0.34, 0.35, 0.23, 0.41, 0.39, 0.39, 0.46] ours26-weighted-t
# [0.2, 0.12, 0.43, 0.5, 0.0, 0.0, 0.64, 0.49, 0.39, 0.46] babacan25

# %%
avgs = []
minmaxs = []
models = list(values)
for m in values:
    #vals = values[m]
    #avg = round(sum(vals)/len(vals),2)
    #minv = min(vals)
    #maxv = max(vals)
    avg = F1_macros[m]
    minv, maxv = F1_minmaxes[m]
    avgs.append(avg)
    minmaxs.append((minv,maxv))
    print(avg, minv, maxv, m)

print(labels)
print(avgs)
print(minmaxs)
plot_bar_from_list_minmax('Model',models,'F1-average,macro',avgs,minmax=minmaxs,x_rotation=20)
# Out:
# 0.14698599065756338 0.14352531767424406 0.14884551907624136 Const(True)
# 0.2794120518819945 0.19602576073164307 0.3335602984440194 arinicheva25
# 0.12455065999051956 0.10467270713782342 0.16121664228785348 LLAMA 3.2
# 0.29260949217388665 0.14651508420072779 0.43044856459330144 QWEN 2
# 0.3683103741323294 0.31110422084675327 0.4175792478077104 QWEN 2.5:7B
# 0.376119776508086 0.3363212326645162 0.39785820918560855 ours26-weighted-t
# 0.323 0.323 0.323 babacan25
# ['All-or-nothing thinking', 'Emotional Reasoning', 'Fortune-telling', 'Labeling', 'Magnification', 'Mental filter', 'Mind Reading', 'Overgeneralization', 'Personalization', 'Should statements']
# [0.14698599065756338, 0.2794120518819945, 0.12455065999051956, 0.29260949217388665, 0.3683103741323294, 0.376119776508086, 0.323]
# ...

# %% [markdown]
# # Comparison of text processing time by LLM models, baseline models and our model

# %%
from time import perf_counter

def extract_text_from_row(row):
    return row.iloc[1] if pd.notna(row.iloc[1]) else row.iloc[0]

texts_for_timing = [extract_text_from_row(row) for _, row in held_df.iterrows()]

# The function shows how long it takes to process a single text.
def benchmark_predictor(texts, predict_one, warmup=True, label="model"):
    if warmup and len(texts) > 0:
        try:
            predict_one(texts[0])
        except Exception as e:
            print(f"[{label}] warmup failed: {e}")

    times = []
    for i, text in enumerate(texts):
        t0 = perf_counter()
        try:
            _ = predict_one(text)
            times.append(perf_counter() - t0)
        except Exception as e:
            times.append(np.nan)
            print(f"[{label}] error on row {i}: {e}")
    return np.asarray(times, dtype=float)

# Consider the average processing time excluding NaN
def mean_seconds(values):
    return float(np.nanmean(values))

llm_configs = [
    ("llama3.2", lambda text: llm_evaluator_top1(all_dists, llm_llama32, text, None, top=1)),
    ("qwen2", lambda text: llm_evaluator_top1(all_dists, llm_qwen2, text, None, top=1)),
    ("qwen2.5:7b", lambda text: llm_evaluator_top1(all_dists, llm_qwen25_7, text, None, top=1)),
]

timing_rows = []

for model_name, predictor in llm_configs:
    t0 = perf_counter()
    times = benchmark_predictor(texts_for_timing, predictor, warmup=True, label=model_name)
    t1 = perf_counter()
    print((t1 - t0) / len(texts_for_timing))
    timing_rows.append({
        "model": model_name,
        "seconds_per_text": mean_seconds(times)
    })

arinicheva25_metricsmap = {'All-or-nothing_thinking':'dichotomous-reasoning',
              'Fortune-telling':'fortune-telling',
              'Mental_filter':'mental-filtering',
              'Overgeneralization':'overgeneralizing',
              'Labeling':'labeling',
              'Mind_Reading':'mindreading',
              'Personalization':'personalizing',
              'Emotional_Reasoning':'emotional-reasoning',
              'Magnification':'magnification',
              'Should_statements':'should-statement'}

ours26_metricsmap = {label: label.replace(" ", "_") for label in all_dists}

def build_metrics_paths(metrics_map, path, lang=""):
    return {
        metric: f"{path}{lang}/{file_name}.txt"
        for metric, file_name in metrics_map.items()
    }

tm_arinicheva25 = TextMetrics(
    build_metrics_paths(arinicheva25_metricsmap, "../../data/models/distortions/ours"),
    encoding="utf-8", metric_logarithmic=True, debug=False)

arinicheva25_predictor = lambda text: our_evaluator_top1(list(arinicheva25_metricsmap), tm_arinicheva25, text, 0.3, top=1)
times = benchmark_predictor(texts_for_timing, arinicheva25_predictor, warmup=True, label="arinicheva25")
timing_rows.append({
    "model": "arinicheva25",
    "seconds_per_text": mean_seconds(times)
})

weighted_run_means = []
weighted_run_details = {}

for split_shift in split_shifts:
    tm_weighted = TextMetrics(
        build_metrics_paths(ours26_metricsmap, f"../../data/models/distortions/shreevastava2021/multiclass-{split_shift+1}-0"),
        encoding="utf-8", metric_logarithmic=True, weighted=True, debug=False)

    predictor = lambda text, tm=tm_weighted: our_evaluator_top1(all_dists, tm, text, 0.5, top=1)
    times = benchmark_predictor(texts_for_timing, predictor, warmup=True, label=f"ours26-weighted[{split_shift+1}]")

    weighted_run_details[f"ours26-weighted[{split_shift+1}]"] = times
    weighted_run_means.append(mean_seconds(times))

timing_rows.append({
    "model": "ours26-weighted",
    "seconds_per_text": float(np.nanmean(weighted_run_means))
})

timing_df = pd.DataFrame(timing_rows)
print(timing_df.to_string(index=False))
# Out:
# 0.3592426567194613
# 0.28530873162057635
# 0.3151702685771683
#           model  seconds_per_text
#        llama3.2          0.349894
#           qwen2          0.273523
#      qwen2.5:7b          0.303206
#    arinicheva25          0.000597
# ours26-weighted          0.000628

# %%
plot_df = timing_df.sort_values("seconds_per_text", ascending=True)

plt.figure(figsize=(10, 4), dpi=300)
bars = plt.bar(plot_df["model"], plot_df["seconds_per_text"])
plt.xlabel("model")
plt.ylabel("seconds per text")
plt.title("Average processing time per text")

plt.xticks(rotation=20, ha="right")

for bar, val in zip(bars, plot_df["seconds_per_text"]):
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height(),
        f"{val:.3f}",
        ha="center",
        va="bottom",
        fontsize=8
    )

plt.tight_layout()
plt.show()

# %%
# Evaluate the computing time budget

grand_t1 = dt.datetime.now()
grand_delta = grand_t1 - grand_t0
str(grand_delta)
# Out:
# '0:31:56.342141'
