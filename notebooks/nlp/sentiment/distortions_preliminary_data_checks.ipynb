# %%
# Dataset: Multiple Distorions (sagarikashreevastava)
# Paper: https://aclanthology.org/2021.clpsych-1.17/
# Data: https://www.kaggle.com/datasets/sagarikashreevastava/cognitive-distortion-detetction-dataset

# !pip install kagglehub
import kagglehub
sagar_path = kagglehub.dataset_download("sagarikashreevastava/cognitive-distortion-detetction-dataset")
print("Path to dataset files:", sagar_path)
# Out:
# Path to dataset files: /Users/akolonin/.cache/kagglehub/datasets/sagarikashreevastava/cognitive-distortion-detetction-dataset/versions/1

# %%
# Dataset: Unclassified distortions (halilbabacan)
# Paper: ???
# Data: https://huggingface.co/datasets/halilbabacan/autotrain-data-cognitive_distortions
# https://huggingface.co/datasets/halilbabacan/autotrain-data-cognitive_distortions/tree/main/raw
# https://huggingface.co/datasets/halilbabacan/autotrain-data-cognitive_distortions/blob/main/raw/Cognitive_distortions.csv

# %%
import os, sys
cwd = os.getcwd()
project_path = cwd[:cwd.find('pygents')+7]
if project_path not in sys.path: sys.path.append(project_path)
os.chdir(project_path)

import pandas as pd

from pygents.aigents_api import tokenize_re
from pygents.util import dictcount
from pygents.plot import plot_dict

import matplotlib as mpl
mpl.rcParams['figure.max_open_warning'] = 0

# %% [markdown]
# ## References
# http://webstructor.net/papers/Kolonin-HP-ACA-IC-text.pdf

# %% [markdown]
# ## Basic data check

# %%
#df = pd.read_csv(r"./notebooks/nlp/sentiment/first dataset dominant and secondary distortions.csv") # with 1st columm dropped
df = pd.read_csv(sagar_path+"/Annotated_data.csv") 
#df = pd.read_csv("./data/corpora/English/distortions/sagarikashreevastava/test.csv")
df = df.drop('Id_Number', axis=1) # delete columnb with id 
df
# Out:
#                                        Patient Question  \
# 0     Hello, I have a beautiful,smart,outgoing and a...
# 1     Since I was about 16 years old I’ve had these ...
# 2      So I’ve been dating on and off this guy for a...
# 3     My parents got divorced in 2004. My mother has...
# 4     I don’t really know how to explain the situati...
# ...                                                 ...
# 2525  I’m a 21 year old female. I spent most of my l...
# 2526  I am 21 female and have not had any friends fo...
# 2527  From the U.S.: My brother is 19 years old and ...
# 2528  From the U.S.: I am a 21 year old woman who ha...
# 2529  I recently moved out on my ex-roommate because...
#
#                                          Distorted part Dominant Distortion  \
# 0     The voice are always fimilar (someone she know...     Personalization
# 1     I feel trapped inside my disgusting self and l...            Labeling
# 2                                                   NaN       No Distortion
# 3                                                   NaN       No Distortion
# 4     I refused to go because I didn’t know if it wa...     Fortune-telling
# ...                                                 ...                 ...
# 2525                                                NaN       No Distortion
# 2526  Now I am at university my peers around me all ...  Overgeneralization
# 2527  He claims he’s severely depressed and has outb...       Mental filter
# 2528                                                NaN       No Distortion
# 2529                                                NaN       No Distortion
#
#      Secondary Distortion (Optional)
# 0                                NaN
# 1                Emotional Reasoning
# 2                                NaN
# 3                                NaN
# 4                Emotional Reasoning
# ...                              ...
# 2525                             NaN
# 2526                             NaN
# 2527                    Mind Reading
# 2528                             NaN
# 2529                             NaN
#
# [2530 rows x 4 columns]

# %%
# Analyzing the frequency of words (tokens) for each cognitive distortion

from collections import defaultdict

# Creating dictionaries for token counting
distortions_dicts = defaultdict(lambda: defaultdict(int))  # A separate dictionary is created for each distortion (distortion-token-token_frequency)
all_tokens_dict = defaultdict(int)  # A general dictionary of all tokens

# Manually define stop words (can be imported from the NLTK library)
# stop_words = {".", ","}

# Loop through the rows of the DataFrame
for _, row in df.iterrows():
    # Text definition: first, check the 2nd column; if NaN, take the text from the 1st column.
    text = row.iloc[1] if pd.notna(row.iloc[1]) else row.iloc[0]
    primary_distortion = row.iloc[2]  # The main cognitive distortion from the 3rd column
    secondary_distortion = row.iloc[3] if pd.notna(row.iloc[3]) else None  # The secondary distortion from the 4th column, if it exists

    # Text tokenization
    tokens = tokenize_re(text)

    # Remove stop words
    # filtered_tokens = [token for token in tokens if token.lower() not in stop_words]
    filtered_tokens = tokens

    dictcount(all_tokens_dict, filtered_tokens)  # Increment the counter in the general dictionary
    dictcount(distortions_dicts[primary_distortion], filtered_tokens)  # Increment the counter for the corresponding primary distortion
    if secondary_distortion:
        dictcount(distortions_dicts[secondary_distortion], filtered_tokens) # Increment the counter for the corresponding secondary distortion (if present)

print("General dictionary of tokens:")
print(dict(all_tokens_dict))

print("\nDictionaries of tokens by distortions:")
for distortion, tokens_dict in distortions_dicts.items():
    print(f"Distortion '{distortion}':")
    print(dict(tokens_dict))
# Out:
# General dictionary of tokens:
# {'the': 3854, 'voice': 38, 'are': 537, 'always': 412, 'fimilar': 1, 'someone': 206, 'she': 1496, 'knows': 41, 'im': 99, 'very': 549, 'concerned': 44, 'about': 938, 'this': 1121, 'and': 6191, 'hope': 26, 'it': 1860, 'has': 817, 'nothing': 125, 'to': 5466, 'do': 745, 'with': 1694, 'my': 3757, 'pregnancy': 7, 'while': 162, 'on': 913, 'active': 11, 'duty': 3, '.': 9374, 'i': 9692, 'feel': 832, 'trapped': 9, 'inside': 41, 'disgusting': 9, 'self': 63, 'like': 928, 'i’m': 950, 'willing': 9, 'anything': 213, 'escape': 7, 'just': 745, 'afraid': 101, 'sometimes': 184, 'that': 2212, 'since': 295, 'not': 1041, 'really': 400, 'thinking': 129, 'during': 95, 'these': 184, 'times': 155, 'might': 76, 'something': 282, 'myself–especially': 1, 'think': 383, 'don’t': 676, 'deserve': 13, 'get': 520, 'help': 288, 'or': 1014, 'worth': 14, 'disturbing': 12, 'people': 409, 'by': 276, 'calling': 24, 'them': 462, 'so': 733, 'i’ve': 434, 'been': 864, 'dating': 66, 'off': 139, 'guy': 89, 'for': 1643, 'almost': 131, '3': 122, 'years': 573, 'he': 2067, 'is': 1888, 'younger': 53, 'than': 150, 'me': 2435, 'our': 284, 'relationship': 283, 'we': 817, 'had': 708, 'issues': 138, 'first': 171, 'wouldn’t': 51, 'call': 65, ',': 6190, 'would': 502, 'prefer': 9, 'go': 279, 'out': 592, 'his': 704, 'friends': 275, 'even': 475, 'remember': 100, 'day': 226, 'of': 2398, 'anniversary': 1, 'things': 393, 'kind': 75, 'tried': 117, 'work': 180, 'all': 622, 'but': 1560, 'felt': 151, 'doesn’t': 200, 'love': 195, 'care': 101, 'though': 136, 'says': 103, 'loves': 28, 'also': 322, 'lied': 19, 'time': 603, 'once': 71, 'went': 128, 'a': 3706, 'party': 7, 'when': 870, 'asked': 107, 'him': 904, 'if': 636, 'did': 174, 'in': 2097, 'face': 49, 'what': 549, 'bothered': 7, 'was': 1653, 'fact': 51, 'pictures': 12, 'dancing': 2, 'rubbing': 3, 'himself': 39, 'another': 137, 'girl': 117, '!': 136, 'after': 273, 'trust': 68, 'told': 254, 'need': 141, 'solve': 1, 'said': 197, 'yeah': 2, 'make': 176, 'again': 116, 'months': 236, 'later': 68, 'found': 97, 'talking': 131, 'over': 268, 'internet': 14, 'met': 78, 'her': 1208, 'knew': 61, 'no': 387, 'lie': 27, 'looking': 53, 'at': 824, 'eyes': 16, 'away': 141, 'trip': 15, 'disappear': 6, 'whole': 55, 'without': 88, 'trying': 124, 'reach': 9, 'phone': 72, 'didn’t': 192, 'have': 1917, 'coverage': 1, 'there': 321, 'that’s': 72, 'why': 170, 'take': 119, 'it…': 5, 'broke': 53, 'up': 551, 'him…i': 1, 'respect': 22, 'because': 723, 'adding': 1, 'girls': 35, 'myspace': 2, 'meet': 22, 'girls…we': 1, '5': 77, 'now': 485, 'asking': 38, 'second': 45, 'chance…we': 1, 'sex': 102, 'breakup': 8, 'only': 304, 'looks': 21, 'whenever': 57, 'wants': 62, 'sex…i': 1, 'still': 223, 'feelings': 104, 'end': 74, 'accepting': 4, 'whatever': 19, 'know': 598, 'good…': 1, '?': 389, 'should': 165, 'give': 85, 'chance': 17, 'forget': 17, 'gonna': 7, 'change': 53, 'an': 419, 'more': 318, 'mature': 7, 'hurt': 104, 'much': 239, 'some': 292, 'anger': 62, 'towards': 45, 'making': 80, 'cry': 46, 'many': 121, 'times…': 1, 'keep': 96, 'getting': 138, 'back': 231, 'every': 175, 'does': 135, 'hurts': 16, 'can': 384, 'better': 103, 'happy': 103, 'much…but': 1, 'going': 253, 'parents': 217, 'got': 202, 'divorced': 38, '2004': 3, 'mother': 231, 'never': 431, 'recovered': 5, 'severe': 52, 'mood': 31, 'swings': 6, 'may': 90, 'be': 822, 'bipolar': 48, 'six': 20, 'old': 280, '1998': 1, 'father': 163, 'moved': 70, 'family': 305, 'germany': 7, 'army': 2, 'amazing': 20, 'childhood': 56, 'twelve': 3, 'iraq': 1, 'thought': 181, 'best': 93, 'brother': 101, 'u': 227, 's': 227, 'where': 197, 'support': 39, 'depressed': 101, 'dad': 138, 'hero': 1, 'blamed': 6, 'mom': 185, 'everything': 175, 'wrong': 134, 'one': 406, 'understood': 5, 'mostly': 47, 'live': 108, 'remote': 1, 'rural': 2, 'part': 73, 'state': 49, 'came': 72, 'wanted': 105, 'divorce': 24, 'from': 926, 'few': 163, 'earlier': 13, 'surgery': 10, 'hip': 3, 'left': 77, 'hospital': 40, 'woman': 77, 'bar': 4, 'they': 553, 'hooked': 2, 'devestated': 1, 'pr ...
#
# Dictionaries of tokens by distortions:
# Distortion 'Personalization':
# {'the': 171, 'voice': 3, 'are': 29, 'always': 29, 'fimilar': 1, 'someone': 18, 'she': 30, 'knows': 2, 'im': 14, 'very': 23, 'concerned': 2, 'about': 41, 'this': 65, 'and': 286, 'hope': 2, 'it': 100, 'has': 26, 'nothing': 4, 'to': 283, 'do': 53, 'with': 77, 'my': 204, 'pregnancy': 1, 'while': 7, 'on': 30, 'active': 1, 'duty': 1, '.': 390, 'i': 634, 'decided': 3, 'wasn‚t': 1, 'going': 12, 'join': 1, 'him': 48, 'again': 4, 'due': 4, 'uneasy': 1, 'feeling': 14, 'gave': 1, 'me': 152, 'which': 20, 'kept': 4, 'from': 25, 'enjoying': 3, 'myself': 52, 'ever': 9, 'since': 13, ',': 279, 'have': 95, 'known': 5, 'in': 72, 'back': 10, 'of': 123, 'mind': 5, 'that': 113, 'he': 34, 'still': 8, 'does': 3, 'believing': 2, 'helps': 1, 'keep': 7, '„faithful‰': 1, 'am': 62, 'no': 22, 'longer': 4, 'interested': 1, 'was': 60, 'a': 140, 'difficult': 5, 'child': 7, 'raise': 1, 'there': 24, 'constant': 1, 'fighting': 1, 'between': 3, 'parents': 6, 'couldn’t': 2, 'talk': 13, 'anyone': 9, 'because': 57, 'had': 22, 'trust': 9, 'adults': 1, 'same': 4, 'goes': 3, 'for': 76, 'life': 25, '–': 1, 'just': 42, 'can’t': 29, 'seem': 13, 'get': 24, 'anything': 15, 'started': 7, ':': 1, 'job': 7, 'applications': 1, 'writing': 1, 'routines': 1, 'relationships': 4, 'opposite': 1, 'sex': 3, 'you': 17, 'name': 1, 'he’s': 5, 'never': 24, 'cheated': 4, 'lied': 1, 'or': 61, 'remotely': 1, 'close': 6, 'been': 26, 'honest': 2, 'fails': 1, 'be': 53, 'affectionate': 1, 'tell': 11, 'how': 25, 'much': 14, 'cares': 1, 'but': 74, 'extremely': 4, 'bad': 11, 'separation': 1, 'anxiety': 9, 'when': 33, 'i’m': 61, 'not': 38, 'want': 30, 'try': 6, 'control': 7, 'who': 6, 'where': 12, 'what': 42, 'doing': 8, 'if': 36, 'involved': 1, 'it’s': 20, 'starting': 5, 'ruin': 2, 'our': 4, 'relationship': 14, 'also': 9, 'feel': 97, 'like': 74, 'lonely': 2, 'at': 32, 'house': 2, 'so': 46, 'don’t': 46, 'know': 37, 'reason': 8, 'cause': 7, 'we': 16, 'different': 2, 'past': 7, 'few': 4, 'years': 9, '5-6': 1, 'finding': 1, 'increasingly': 1, 'hard': 12, 'make': 13, 'friends': 18, 'them': 27, '2': 6, 'grandparents': 2, 'died': 6, 'recenently': 1, 'things': 21, 'gotten': 2, 'worse': 6, 'start': 7, 'cant': 7, 'focus': 1, 'class': 3, 'before': 11, 'getting': 5, 'harder': 3, 'deal': 7, 'can': 22, 'process': 4, 'million': 1, 'head': 7, 'once': 2, 'put': 9, 'paper': 1, 'is': 83, 'why': 17, 'got': 10, 'zero': 1, 'last': 1, 'test': 1, 'even': 22, 'though': 11, 'every': 9, 'question': 3, 'right': 12, 'help': 6, '?': 21, 'connection': 1, 'early': 2, 'brain': 2, 'health': 2, 'major': 2, 'recurrent': 1, 'depression': 7, 'swore': 1, 'would': 19, 'cheat': 1, 'husband': 2, 'forgave': 1, 'cheating': 1, 'married': 2, 'guy': 3, 'broke': 2, 'up': 31, 'guy’s': 1, 'marriage': 1, 'didn’t': 9, 'love': 9, 'suffering': 1, 'bulimia': 2, 'four': 1, 'months': 6, 'now': 23, 'realize': 6, 'risks': 1, 'problem': 5, 'trying': 7, 'stop': 12, 'month': 3, 'success': 1, 'healthy': 2, 'fear': 5, 'all': 42, 'work': 10, 'completed': 2, 'over': 11, 'person': 13, 'down': 14, 'drain': 2, 'some': 9, 'self': 3, 'esteem': 3, 'issues': 6, 'will': 13, 'continue': 2, 'any': 14, 'advice': 2, 'tricks': 1, 'these': 11, 'behaviors': 3, 'seemed': 3, 'become': 4, 'habitual': 1, 'uncontrollable': 2, 'dealt': 1, 'problems': 7, 'give': 5, 'shot': 3, 'time': 26, 'staying': 1, 'attracted': 1, 'women': 1, 'date': 1, 'most': 7, 'considered': 1, 'attractive': 1, 'come': 2, 'off': 7, 'as': 41, 'shallow': 1, 'definitely': 3, 'supportive': 1, 'needed': 2, 'well': 5, 'felt': 13, 'gone': 1, 'far': 6, 'could': 14, 'haveing': 1, 'adhd': 1, 'schooling': 1, 'failing': 2, 'improve': 2, 'depressed': 10, 'doubted': 1, 'took': 4, 'their': 7, 'yes': 2, 'analyses': 1, 'everything': 14, 'an': 14, 'extent': 2, 'terribly': 1, 'drained': 1, 'tired': 2, 'thinking': 10, 'such': 7, 'simple': 3, 'dont': 6, 'being': 20, 'making': 8, 'doubting': 1, 'guessing': 1, 'think': 21, 'they': 27, 'might': 5, '99%': 1, 'times': 6, 'wrong': 27, 'insecure': 2, 'person…does': 1, 'mean': 3, 'makes': 22, ...
# Distortion 'Labeling':
# {'i': 523, 'feel': 80, 'trapped': 1, 'inside': 5, 'my': 141, 'disgusting': 4, 'self': 7, 'and': 339, 'like': 69, 'i’m': 101, 'willing': 1, 'to': 253, 'do': 43, 'anything': 10, 'escape': 3, 'it': 74, '.': 397, 'just': 31, 'afraid': 9, 'sometimes': 12, 'that': 100, 'since': 11, 'not': 62, 'really': 24, 'thinking': 9, 'during': 5, 'these': 9, 'times': 14, 'might': 2, 'something': 15, 'myself–especially': 1, 'think': 25, 'don’t': 50, 'deserve': 1, 'get': 25, 'help': 7, 'or': 49, 'worth': 1, 'disturbing': 1, 'people': 27, 'by': 11, 'calling': 1, 'them': 22, 'thought': 13, 'he': 57, 'displayed': 1, 'traits': 2, 'of': 123, 'honor': 1, ',': 365, 'loyalty': 1, 'integrity': 1, 'honesty': 1, 'kind-heartedness': 1, 'as': 34, 'well': 5, 'characteristics': 1, 'a': 188, 'hard': 7, 'worker': 1, 'an': 25, 'overall': 1, 'well-rounded': 2, 'individual': 1, 'am': 60, 'highly': 1, 'disorganized': 1, 'concerned': 3, 'with': 76, 'being': 14, 'diagnosed': 2, 'schizophrenia': 2, 'we': 15, 'had': 20, 'the': 136, 'storybook': 1, 'romance': 1, ':': 3, 'were': 8, 'always': 30, 'happy': 7, 'never': 14, 'argued': 2, 'tired': 2, 'each': 2, 'other': 15, 'all': 28, 'friends': 20, 'family': 17, 'looked': 1, 'at': 29, 'us': 9, 'having': 11, 'perfect': 5, 'relationship': 14, 'have': 94, 'grown': 2, 'very': 37, 'much': 10, 'but': 79, 'has': 38, 'will': 21, 'deal': 5, 'any': 15, 'issues': 4, 'between': 1, 'is': 104, 'immature': 1, 'accepts': 1, 'responsibility': 2, 'for': 61, 'his': 13, 'part': 3, 'in': 76, 'problem': 8, 'everything': 18, 'fault': 2, 'according': 1, 'him': 20, 'there': 12, 'been': 27, 'where': 11, 'figured': 1, 'why': 14, 'should': 7, 'even': 28, 'live': 6, 'nothing': 7, 'ever': 8, 'good': 11, 'enough': 6, 'mostly': 2, 'failure': 10, 'realized': 2, 'major': 2, 'internal': 2, 'lack': 5, 'identity': 1, 'interests': 3, 'emotions': 3, 'therefore': 1, 'trouble': 4, 'social': 6, 'interaction': 1, 'hopelessly': 1, 'apathetic': 3, 'heart': 4, 'know': 47, 'how': 19, 'reconcile': 1, 'true': 5, '‘me’': 1, 'image': 2, 'others': 6, 'expect–that': 1, '‘normal’': 1, 'person': 30, 'who': 20, 'passions': 1, 'desires': 1, 'care': 5, 'about': 36, 'nothing–not': 1, 'politics': 1, 'current': 2, 'events': 2, 'sports': 1, 'music': 1, 'art': 1, 'outwardly': 1, 'high-achieving': 1, 'student': 2, 'occasionally': 2, 'particularly': 1, 'poignant': 1, 'tragedy': 1, 'example': 1, 'make': 7, 'helping': 2, 'out': 21, 'on': 43, 'whole': 2, 'completely': 7, 'same': 7, 'goes': 3, 'aspects': 1, 'life': 16, 'childhood': 2, 'friendships': 4, 'are': 25, 'normal': 7, 'emotional': 3, 'connections': 1, 'anyone': 6, ';': 7, 'if': 26, 'somebody': 1, '‘close’': 1, 'me': 107, 'died': 3, 'would': 14, 'only': 14, 'be': 58, 'affect': 2, 'own': 6, 'convenience': 1, 'academic': 1, 'athletic': 1, 'arts-related': 1, 'either': 4, 'believe': 9, 'exposure': 1, 'im': 5, 'sure': 8, 'she': 65, 'disorder': 3, 'some': 8, 'sort…': 1, 'lies': 2, 'constantly': 3, 'tells': 2, 'story': 2, '3': 2, 'week': 3, 'its': 5, 'changing…': 1, 'now': 27, 'this': 39, 'woman': 3, 'because': 55, 'last': 5, 'while': 5, 'trying': 8, 'calm': 1, 'her': 44, 'took': 2, 'blame': 1, 'everything…admitted': 1, 'was': 55, 'wrong': 13, 'etc': 4, 'cut': 2, 'off…': 1, 'another': 3, 'man': 3, 'picture': 1, 'coaching': 1, 'along': 3, 'set': 4, 'up': 22, 'dosent': 1, 'go': 8, 'away': 4, 'when': 23, 'fun': 3, 'back': 6, 'mind': 4, 'schizo': 1, 'crazy': 10, 'used': 9, 'loving': 4, '&': 7, 'caring': 3, 'unsociable': 1, 'uncaring': 3, 'no': 26, 'remorse': 2, 'depressed': 11, 'first': 4, 'got': 8, 'together': 3, 'our': 9, 'awhile': 1, 'decided': 2, 'take': 3, 'next': 2, 'level': 2, 'attentive': 1, 'made': 8, 'special': 1, 'incredibly': 1, 'jealous': 6, 'girlfriend': 2, 'before': 3, 'so': 51, 'basically': 2, 'far': 5, 'from': 30, 'real': 4, 'hidden': 1, 'find': 14, 'pleasure': 1, 'shame': 2, 'also': 16, 'fantasies': 2, 'nowadays': 1, 'force': 2, 'myself': 39, 'fantasy': 2, 'order': 1, 'orgasm': 1, 'doesn’t': 9, 'naturally': 1, 'come': 3, 'into': 7,  ...
# Distortion 'Emotional Reasoning':
# {'i': 518, 'feel': 117, 'trapped': 2, 'inside': 10, 'my': 137, 'disgusting': 2, 'self': 6, 'and': 205, 'like': 88, 'i’m': 71, 'willing': 1, 'to': 230, 'do': 39, 'anything': 16, 'escape': 2, 'it': 87, '.': 318, 'just': 38, 'afraid': 25, 'sometimes': 12, 'that': 106, 'since': 14, 'not': 56, 'really': 21, 'thinking': 11, 'during': 4, 'these': 13, 'times': 5, 'might': 9, 'something': 20, 'myself–especially': 1, 'think': 14, 'don’t': 37, 'deserve': 1, 'get': 23, 'help': 9, 'or': 47, 'worth': 3, 'disturbing': 1, 'people': 17, 'by': 10, 'calling': 2, 'them': 12, 'refused': 1, 'go': 16, 'because': 46, 'didn’t': 2, 'know': 24, 'if': 33, 'was': 29, 'going': 25, 'on': 23, 'record': 1, 'which': 4, 'could': 10, 'possibly': 3, 'affect': 1, 'dreams': 1, 'of': 98, 'becoming': 4, 'a': 86, 'psychiatrist': 1, 'have': 90, 'major': 1, 'fear': 16, 'choking': 1, 'drowningit': 1, 'seems': 3, 'everytime': 1, 'so': 35, 'close': 4, 'beating': 1, 'in': 66, ',': 206, 'nocked': 1, 'right': 5, 'back': 10, 'down': 4, 'the': 118, 'bottom': 1, 'everything': 9, 'perfect': 2, 'trusted': 2, 'him': 22, 'whole-heartedly': 1, 'up': 14, 'until': 4, 'recently': 3, 'i’ve': 16, 'been': 26, 'very': 17, 'suspicious': 1, 'trust': 12, 'keeps': 2, 'started': 5, 'lose': 3, 'when': 25, 'finding': 3, 'text': 1, 'message': 1, 'his': 7, 'phone': 2, 'from': 14, 'someone': 17, '“': 9, 'babe': 1, '”': 11, 'valentines': 1, 'day': 7, 'he': 24, 'said': 5, 'nothing': 10, 'asked': 3, 'see': 8, 'rest': 2, 'messages': 2, 'person': 8, 'but': 63, 'no': 21, 'thought': 7, 'would': 15, 'change': 2, 'dynamics': 1, 'our': 6, 'relationship': 10, 'am': 71, 'supposed': 4, 'let': 4, 'ever': 4, 'occasion': 1, 'it’s': 24, 'hard': 7, 'for': 44, 'me': 108, 'did': 8, 'beginning': 3, 'almost': 3, 'convincing': 1, 'myself': 24, 'this': 39, 'feeling': 14, 'should': 4, 'end': 5, 'before': 4, 'hurt': 4, 'wait': 2, 'out': 21, 'can': 12, 'become': 2, 'as': 36, 'good': 4, '?': 4, 'can’t': 33, 'what': 32, 'say': 9, 'parents': 4, 'they’re': 2, 'face': 4, 'yelling': 2, 'about': 39, 'how': 18, 'forgot': 1, 'yell': 1, 'its': 6, 'disrespect': 1, 'they': 20, 'respect': 2, 'avoid': 2, 'confrontations': 1, 'only': 10, 'way': 5, 'is': 64, 'completely': 5, 'ignore': 1, 'whole': 2, 'family': 5, 'doing': 9, 'sleeping': 3, 'all': 26, 'schoolwork': 1, 'suffering': 1, 'also': 13, 'barely': 2, 'eat': 3, 'arguments': 1, 'always': 22, 'seem': 10, 'find': 11, 'their': 10, 'into': 11, 'life': 17, 'he’s': 6, 'never': 12, 'cheated': 3, 'lied': 1, 'remotely': 1, 'honest': 1, 'with': 42, 'fails': 1, 'be': 26, 'affectionate': 1, 'tell': 9, 'much': 10, 'cares': 1, 'extremely': 6, 'bad': 3, 'separation': 1, 'anxiety': 9, 'want': 21, 'try': 5, 'control': 12, 'who': 5, 'where': 5, 'goes': 2, 'involved': 1, 'starting': 2, 'ruin': 1, 'lonely': 1, 'at': 17, 'house': 3, 'reason': 11, 'cause': 5, 'we': 11, 'are': 26, 'different': 4, 'past': 6, 'few': 4, 'years': 6, 'haven’t': 3, 'getting': 9, 'used': 2, 'anger': 3, 'happiness': 4, 'joy': 2, 'even': 17, 'sadness': 3, 'left': 4, 'things': 11, 'give': 1, 'emotional': 3, 'pleasure': 2, 'now': 18, 'entertain': 1, 'occupy': 1, 'mind': 11, 'ups': 1, 'downs': 1, 'teenagers': 1, 'kind': 3, 'flat': 1, 'dips': 1, 'real': 5, 'anymore': 7, 'world': 4, 'feels': 10, 'dreamy': 1, 'constantly': 7, 'withdrawn': 1, 'live': 3, 'unlike': 1, 'though': 7, 'each': 2, 'other': 7, 'occasionally': 1, 'talk': 8, 'comfort': 2, 'child': 2, 'sad': 1, 'watchful': 1, 'one': 13, 'impression': 1, 'forget': 1, 'what’s': 2, 'others': 6, 'controlling': 1, 'body': 3, 'sexually': 2, 'arousing': 1, 'worried': 3, 'later': 2, 'will': 21, 'away': 7, 'horrible': 1, 'guilty': 2, 'sure': 8, 'us': 6, 'literally': 2, 'daily': 2, 'basis': 1, 'snapping': 1, 'everyone': 5, 'dealing': 2, 'normal': 7, 'issues': 6, 'overwhelmed': 3, 'basically': 2, 'has': 11, 'far': 2, 'hidden': 1, 'shame': 1, 'fantasies': 1, 'nowadays': 1, 'force': 3, 'fantasy': 1, 'order': 2, 'orgasm': 1, 'doesn’t': 9, 'naturally': 1, 'come': 4, 'properly': 2, 'aroused': 1, 'still': ...
# Distortion 'No Distortion':
# {'so': 458, 'i’ve': 266, 'been': 653, 'dating': 53, 'on': 674, 'and': 4129, 'off': 92, 'this': 745, 'guy': 70, 'for': 1177, 'almost': 90, '3': 105, 'years': 480, '.': 6678, 'he': 1693, 'is': 1293, 'younger': 40, 'than': 107, 'me': 1446, 'during': 69, 'our': 237, 'relationship': 207, 'we': 688, 'had': 533, 'always': 212, 'issues': 95, 'first': 140, 'wouldn’t': 43, 'call': 47, ',': 4123, 'would': 349, 'prefer': 7, 'to': 3549, 'go': 178, 'out': 414, 'with': 1222, 'his': 594, 'friends': 176, 'even': 283, 'remember': 76, 'the': 2742, 'day': 153, 'of': 1580, 'anniversary': 1, 'or': 587, 'things': 223, 'like': 433, 'that': 1401, 'kind': 48, 'tried': 76, 'work': 131, 'all': 368, 'but': 989, 'felt': 81, 'really': 222, 'doesn’t': 117, 'love': 144, 'care': 64, 'about': 591, 'though': 77, 'says': 80, 'loves': 17, 'also': 223, 'has': 643, 'lied': 13, 'time': 413, 'once': 57, 'went': 106, 'a': 2734, 'party': 4, 'when': 619, 'i': 5594, 'asked': 94, 'him': 699, 'if': 363, 'did': 135, 'in': 1531, 'my': 2518, 'face': 35, 'what': 338, 'bothered': 6, 'was': 1305, 'fact': 25, 'pictures': 10, 'dancing': 2, 'rubbing': 3, 'himself': 29, 'another': 103, 'girl': 97, '!': 87, 'after': 223, 'trust': 30, 'told': 213, 'need': 90, 'help': 219, 'solve': 1, 'said': 174, 'yeah': 2, 'make': 103, 'again': 87, 'months': 192, 'later': 53, 'found': 81, 'talking': 90, 'over': 180, 'internet': 9, 'met': 65, 'her': 942, 'knew': 38, 'no': 207, 'lie': 8, 'looking': 39, 'at': 574, 'eyes': 10, 'away': 91, 'trip': 14, 'disappear': 3, 'whole': 23, 'without': 54, 'trying': 73, 'reach': 6, 'phone': 56, 'didn’t': 134, 'have': 1242, 'coverage': 1, 'there': 215, 'that’s': 49, 'why': 104, 'take': 81, 'it…': 3, 'broke': 43, 'up': 368, 'him…i': 1, 'think': 181, 'respect': 15, 'because': 375, 'adding': 1, 'girls': 27, 'myspace': 1, 'meet': 14, 'girls…we': 1, '5': 68, 'now': 313, 'asking': 27, 'second': 35, 'chance…we': 1, 'sex': 87, 'breakup': 7, 'only': 215, 'looks': 15, 'whenever': 34, 'wants': 47, 'sex…i': 1, 'still': 159, 'feelings': 65, 'end': 41, 'accepting': 4, 'whatever': 12, 'know': 329, 'it': 1173, 'not': 684, 'good…': 1, 'do': 453, '?': 313, 'should': 97, 'give': 57, 'chance': 11, 'just': 445, 'forget': 12, 'gonna': 3, 'change': 28, 'an': 301, 'more': 206, 'mature': 7, 'hurt': 75, 'much': 143, 'feel': 256, 'some': 213, 'anger': 41, 'towards': 28, 'making': 42, 'cry': 15, 'many': 82, 'times…': 1, 'keep': 57, 'getting': 91, 'back': 172, 'every': 103, 'does': 99, 'something': 142, 'hurts': 7, 'can': 232, 'get': 299, 'someone': 133, 'better': 57, 'happy': 53, 'don’t': 343, 'much…but': 1, 'going': 144, 'parents': 159, 'got': 150, 'divorced': 36, '2004': 2, 'mother': 172, 'never': 268, 'recovered': 4, 'she': 1179, 'severe': 42, 'mood': 15, 'swings': 3, 'may': 55, 'be': 490, 'bipolar': 38, 'six': 17, 'old': 248, '1998': 1, 'father': 137, 'moved': 61, 'family': 214, 'germany': 7, 'army': 2, 'amazing': 13, 'childhood': 41, 'twelve': 3, 'iraq': 1, 'thought': 98, 'best': 64, 'brother': 81, 'u': 226, 's': 221, 'where': 125, 'support': 31, 'very': 376, 'depressed': 52, 'dad': 99, 'hero': 1, 'blamed': 3, 'mom': 136, 'everything': 69, 'wrong': 59, 'one': 267, 'understood': 4, 'mostly': 32, 'live': 75, 'remote': 1, 'rural': 2, 'part': 47, 'state': 36, 'came': 60, 'wanted': 87, 'divorce': 23, 'from': 769, 'few': 131, 'earlier': 9, 'surgery': 7, 'hip': 2, 'left': 57, 'hospital': 37, 'woman': 65, 'bar': 4, 'they': 342, 'hooked': 2, 'devestated': 1, 'promised': 8, 'he’d': 7, 'hello': 50, 'friend': 117, 'since': 205, 'grade': 27, '6th': 8, 'were': 202, 'same': 98, 'pals': 1, 'each': 86, 'other': 227, 'two': 119, 'realized': 21, 'unconditionally': 1, 'shared': 8, 'merely': 2, 'friendship': 15, 'mutual': 3, 'common': 11, 'proposed': 2, 'refused': 16, 'everybody': 6, 'including': 16, 'cousin': 13, 'who': 205, 'are': 359, 'good': 96, 'too': 100, 'taken': 27, 'wrongly': 1, 'such': 52, 'certainly': 6, 'stopped': 42, 'contacts': 2, '8': 39, 'loved': 25, 'n': 1, 'concerned': 30, 'kept': 37, 'detail': ...
# Distortion 'Fortune-telling':
# {'i': 605, 'refused': 1, 'to': 316, 'go': 18, 'because': 72, 'didn’t': 4, 'know': 48, 'if': 67, 'it': 103, 'was': 32, 'going': 31, 'on': 29, 'my': 184, 'record': 1, 'which': 7, 'could': 21, 'possibly': 1, 'affect': 2, 'dreams': 2, 'of': 153, 'becoming': 3, 'a': 120, 'psychiatrist': 1, '.': 339, 'have': 84, 'major': 1, 'fear': 18, 'choking': 1, 'and': 289, 'drowningit': 1, 'seems': 5, 'like': 62, 'everytime': 1, 'get': 53, 'so': 49, 'close': 6, 'beating': 2, 'in': 77, ',': 238, 'nocked': 1, 'right': 8, 'back': 11, 'down': 6, 'the': 153, 'bottom': 1, 'had': 13, 'call': 7, 'off': 8, 'work': 10, 'friday': 1, 'can’t': 26, 'leave': 13, 'him': 39, 'alone': 8, 'at': 29, 'apartment': 2, 'he': 39, 'will': 90, 'do': 47, 'something': 28, 'me': 134, 'evicted': 1, 'or': 68, 'worse': 12, 'i’m': 93, 'end': 9, 'ropes': 1, 'don’t': 69, 'what': 31, 'during': 3, 'this': 57, 'time': 25, 'recruited': 1, 'many': 9, 'great': 3, 'jobs': 1, 'but': 83, 'scared': 33, 'take': 7, 'them': 22, 'instead': 3, 'started': 3, 'own': 4, 'dot-com': 1, 'business': 1, 'trip': 1, 'sucked': 1, 'wasn’t': 1, 'interested': 2, 'based': 1, 'his': 16, 'saying': 6, 'attitude': 1, 'stated': 1, 'drinkingi': 1, 'want': 40, 'believe': 10, 'feeling': 9, 'small': 2, 'claims': 1, 'court': 1, 'for': 52, 'our': 4, 'family': 17, 'unit': 1, 'is': 71, 'savable': 1, 'would': 39, 'therapy': 6, 'help': 15, 'should': 7, 'be': 69, 'bad': 16, 'mother': 8, 'lose': 4, 'medication': 1, 'resistant': 1, 'tried': 5, 'all': 32, 'medications': 3, 'out': 30, 'there': 13, 'depression': 5, 'bipolari': 1, 'how': 28, 'find': 10, 'best': 2, 'dr': 1, 'am': 70, 'afraid': 36, 'cognitive': 1, 'loss': 2, 'memory': 1, 'dosent': 1, 'away': 9, 'when': 33, 'having': 6, 'fun': 1, 'an': 14, 'trying': 6, 'not': 64, 'think': 38, 'about': 46, 'its': 10, 'always': 21, 'mind': 7, 'that': 130, 'schizo': 1, 'everything': 12, 'crazy': 6, 'one': 30, 'person': 13, 'knows': 3, 'ed': 1, 'even': 24, 'though': 11, 'need': 10, '18': 2, 'can': 25, 'without': 6, 'knowing': 1, 'big': 2, 'deal': 7, 'let': 8, 'they': 34, 'lot': 8, 'with': 68, 'now': 26, 'plus': 2, 'does': 7, 'really': 23, 'understand': 3, 'things': 28, 'father': 2, 'stay': 4, 'from': 15, 'tell': 19, 'either': 7, 'whole': 3, 'dynamic': 1, 'screwy': 1, 'we': 17, 'been': 14, 'dating': 1, '7': 1, 'months': 2, 'parents': 11, 'approve': 2, 'recently': 4, 'checked': 2, 'email': 1, 'wrong': 8, 'he’ll': 8, 'ever': 10, 'forgive': 2, 'cause': 4, 'problems': 4, 'relationship': 6, 'over': 17, 'stupidity': 1, 'being': 19, 'insecure': 2, 'knew': 7, 'needed': 1, 'make': 16, 'myself': 32, 'turn': 4, 'into': 11, 'dont': 4, 'serious': 2, 'as': 54, 'soon': 4, 'step': 1, 'house': 5, 'feels': 4, 'im': 12, 'watched': 1, 'by': 5, 'these': 5, 'people': 15, 'around': 9, 'nice': 2, 'sort': 3, 'haunts': 2, 'mei': 1, 'feel': 75, 'very': 14, 'misjudged': 1, 'that’s': 5, 'happens': 3, 'sometimes': 16, 'may': 13, 'stop': 13, 'worrying': 5, 'confidence': 1, 'change': 6, 'happen': 11, 'last': 3, 'year': 3, 'every': 7, 'possible': 4, 'area': 1, 'life': 17, 'thinking': 11, 'patterns': 1, 'just': 40, 'seem': 5, 'more': 16, 'prominent': 1, 'pretty': 4, 'where': 11, 'lead': 3, 'antidepressant': 1, 'epilepsy': 1, 'any': 25, 'seizures': 1, 'ashamed': 2, 'anybody': 1, 'doctor': 5, 'angry': 4, 'her': 52, 'whenever': 1, 'she': 50, 'tries': 1, 'she’ll': 4, 'better': 11, 'complete': 3, 'lie': 5, 'despise': 1, 'getting': 12, 'lied': 1, 'happened': 4, 'too': 9, 'times': 5, 'worried': 18, 'disruption': 1, 'attachment': 1, 'move': 5, 'region': 1, 'country': 2, 'employment': 2, 'opportunities': 1, 'varied': 1, 'pertain': 1, 'career': 3, 'field': 3, 'pay': 2, ';': 5, 'however': 4, 'inability': 1, 'making': 5, 'goal': 1, 'nearly': 2, 'impossible': 2, 'achieve': 1, 'simply': 2, 'cannot': 10, 'never': 24, 'felt': 5, 'came': 1, 'basically': 2, 'why': 7, 'controlling': 1, 'refusing': 1, 'urges': 3, 'talk': 8, 'whoever': 1, 'fail': 2, 'it’s': 9, 'relatively': 1, 'long': 6, 'supposed': 1, 'cant': 8, 'thing': 10, 'express': 2, 'l ...
# Distortion 'Magnification':
# {'i': 716, 'felt': 12, 'like': 97, 'the': 194, 'response': 1, 'was': 53, 'totally': 6, 'irrational': 2, ',': 381, 'mean': 6, 'and': 375, 'disrespectful': 2, '.': 496, 'extremely': 3, 'hurt': 8, 'why': 10, 'can': 33, 'she': 34, 'look': 9, 'that': 141, 'but': 80, 'have': 118, 'to': 302, 'work': 7, 'keep': 11, 'myself': 42, 'healthy': 1, '?': 14, 'are': 19, 'such': 8, 'high': 2, 'expectations': 1, 'put': 6, 'on': 45, 'me': 177, 'doesn’t': 12, 'live': 6, 'up': 44, 'is': 103, 'my': 230, 'biggest': 1, 'role': 1, 'model': 1, 'all': 41, 'think': 31, 'of': 152, 'at': 49, 'this': 79, 'moment': 5, 'starving': 1, 'until': 8, 'her': 36, 'when': 57, 'she’s': 2, 'not…my': 1, 'motivation': 1, 'goes': 1, 'away': 15, 'want': 32, 'restrict': 1, 'parents': 6, 'saying': 10, 'they': 35, 'die': 6, 'leave': 7, 'everyday': 4, 'come': 6, 'from': 28, 'school': 11, 'we': 14, 'do': 39, 'house': 9, 'argue': 2, 'about': 67, 'every': 15, 'little': 18, 'thing': 10, 'mom': 11, 'feel': 79, 'bursting': 1, 'into': 16, 'tears': 3, 'dont': 8, 'it': 148, 'in': 102, 'sometimes': 12, 'im': 9, 'arguing': 1, 'with': 69, 'its': 7, 'so': 60, 'hard': 8, 'for': 80, 'take': 8, 'things': 38, 'tell': 9, 'get': 45, 'depressed': 7, 'show': 5, 'emotions': 3, 'say': 7, 'no': 39, 'heart': 7, 'forever': 5, 'i’m': 82, 'not': 41, 'sure': 5, 'what': 31, 'help': 12, 'him': 33, 'us': 5, 'going': 20, 'literally': 6, 'lose': 3, 'mind': 15, 'a': 188, 'daily': 2, 'basis': 2, 'end': 6, 'snapping': 1, 'everyone': 5, 'or': 84, 'dealing': 2, 'normal': 5, 'issues': 7, 'because': 50, 'overwhelmed': 3, 'can’t': 45, 'stop': 13, 'laughing': 1, 'quoting': 1, 'songs': 1, 'lines': 1, 'movies…or': 1, 'obscene': 1, '“': 21, 'vertabrae': 1, 'feels': 6, 'carnivorous': 1, 'dairy': 1, 'product': 1, '”': 21, 'yes': 1, 'obviously': 1, 'could': 16, 'be': 47, 'mania': 1, 'i’ve': 34, 'been': 41, 'having': 9, 'problems': 7, 'past': 8, 'couple': 5, 'months': 7, 'also': 12, 'hearing': 5, 'seeing': 6, 'too': 10, 'people': 24, 'talking': 8, 'bad': 20, 'usually': 2, 'friends’': 1, 'family’s': 1, 'voices': 3, 'you’re': 3, 'worthless': 4, 'stupid': 1, 'pathetic': 1, 'ugly': 1, 'blah': 3, 'lot': 16, 'time': 36, 'hear': 8, 'alone': 3, 'one': 28, 'there': 19, 'which': 13, 'scares': 3, 'year': 10, 'ago': 11, 're-entered': 1, 'serious': 3, 'relationship': 6, 'an': 28, 'ex-boyfriend': 1, 'he': 45, 'essentially': 1, 'only': 15, '‘real’': 1, 'ex': 2, 'were': 9, 'together': 5, 'through': 10, 'both': 3, 'our': 5, 'college': 2, 'careers': 1, 'apart': 1, 'before': 8, 'got': 9, 'back': 5, 'we’ve': 2, 'neither': 1, 'has': 38, 'ever': 8, 'cheated': 1, 'other': 16, 'some': 19, 'reason': 13, 'find': 9, 'constantly': 9, 'paranoid': 3, 'will': 21, 'always': 18, 'had': 35, 'real': 4, 'health': 3, 'family': 14, 'treated': 1, 'piece': 1, 'crap': 1, 'recently': 6, 'it’s': 29, 'gotten': 4, 'worse': 9, 'grandma’s': 1, 'friend': 1, 'told': 3, 'grandma': 1, 'lie': 4, 'claiming': 1, 'said': 4, '‘i’d': 1, 'cut': 5, 'off': 11, 'girls’': 1, 'fingers': 1, 'if': 38, 'came': 3, 'room': 7, '!': 20, 'now': 34, 'total': 1, 'would': 24, 'actually': 6, 'girl': 3, 'xd': 1, 'what’s': 2, 'wrong': 9, 'agh': 1, 'need': 10, 'sleep': 9, 'dead': 3, 'saw': 4, 'sister': 1, 'fireplace': 1, 'ugh': 1, 'don’t': 43, 'know': 33, 'happens': 2, 'nightly': 1, 'should': 3, 'happening': 2, 'schizophrenia': 2, 'something': 30, 'trouble': 2, 'wife’s': 1, 'suspicious': 1, 'nature': 1, 'never': 17, 'trusts': 1, 'any': 19, 'problem': 8, 'magnitude': 1, 'am': 66, 'suffocated': 1, 'very': 42, 'much': 24, 'frustrated': 2, 'blur': 2, 'life': 33, 'absolutely': 7, 'cannot': 14, 'remember': 2, 'right': 8, 'started': 14, '4': 2, '5': 3, 'then': 16, '2': 2, '3': 3, 'years': 18, 'completely': 6, 'lost': 9, 'though': 8, 'here': 2, 'late': 5, 'centers': 1, 'around': 14, 'place': 2, 'stayed': 2, 'just': 44, 'wondering': 3, 'maybe': 3, 'blocked': 1, 'out': 31, 'span': 1, 'those': 4, 'kid': 3, 'thinks': 1, 'listening': 3, 'tapping': 1, 'pencil': 1, 'staring': 1, 'window': 2, 'moving': 1, 'feet': 2, ' ...
# Distortion 'Mind Reading':
# {'i': 667, 'attributed': 1, 'his': 42, 'behavior': 10, 'to': 400, 'stress': 3, '–': 2, 'he': 130, 'owned': 1, 'a': 149, 'business': 1, 'that': 190, 'has': 46, 'since': 17, 'failed': 1, 'don’t': 72, 'know': 49, 'if': 62, 'she’s': 13, 'trying': 12, 'protect': 2, 'me': 264, 'because': 90, 'she': 147, 'knows': 8, 'how': 42, 'bad': 18, 'it': 121, 'would': 35, 'hurt': 6, 'they': 80, 'actually': 13, 'did': 13, ',': 347, 'or': 75, 'really': 40, 'didn’t': 15, 'have': 85, 'full': 6, 'on': 39, 'sex': 1, 'with': 84, 'him': 57, '.': 467, 'feel': 103, 'like': 97, 'split': 1, 'personalities': 1, 'many': 6, 'times': 11, 'doesn’t': 35, 'remember': 4, 'tasks': 2, 'completed': 1, 'days': 5, 'ago': 7, 'we': 30, 'are': 43, 'at': 56, 'stressful': 2, 'time': 30, 'in': 104, 'our': 13, 'relationship': 16, 'which': 15, 'includes': 1, 'the': 196, '6': 1, 'month': 4, 'old': 8, 'baby': 5, 'used': 6, 'be': 59, 'best': 9, 'friends': 16, 'and': 377, 'still': 11, 'today': 1, 'sometimes': 16, 'enjoy': 4, 'shared': 1, 'but': 100, 'see': 10, 'more': 19, 'no': 27, 'idea': 5, 'of': 129, 'what': 45, 'i’m': 104, 'referring': 1, 'asks': 1, '“': 17, 'huh': 1, '?': 11, '”': 16, 'all': 36, 'there': 17, 'been': 30, 'lingering': 1, 'problems': 9, 'understand': 18, 'any': 10, 'this': 65, 'falling': 1, 'deeply': 1, 'into': 13, 'depression': 9, 'myself': 21, 'along': 4, 'weight': 3, 'can’t': 34, 'shed': 3, 'ask': 4, 'for': 97, 'truth': 1, 'will': 50, 'simply': 5, 'look': 6, 'face': 5, 'tell': 33, 'another': 11, 'lie': 5, '{i': 1, 'bear': 2, 'seriously.}': 1, 'when': 41, 'someone': 8, 'tries': 1, 'talk': 26, 'get': 42, 'so': 53, 'nervous': 2, 'about': 81, 'think': 61, 'end': 9, 'up': 26, 'seeming': 1, 'uninterested': 1, 'maybe': 11, 'even': 41, 'snobby': 1, 'probably': 7, 'im': 24, 'always': 41, 'thinking': 21, 'people': 62, 'talking': 16, 'behind': 2, 'my': 203, 'back': 12, 'badly': 2, 'whenever': 7, 'whispering': 1, 'person': 20, 'pretty': 3, 'much': 17, 'assume': 4, 'panick': 1, 'school': 9, 'caught': 1, 'worrying': 3, 'smell': 1, 'makeup': 2, 'is': 121, 'smeared': 1, 'immagine': 1, 'everyone': 23, 'looking': 4, 'funny': 2, 'loser': 1, 'wont': 2, 'leave': 8, 'house': 5, 'without': 11, 'am': 53, 'horrified': 1, 'other': 25, 'trip': 1, 'sucked': 1, 'wasn’t': 4, 'interested': 3, 'based': 1, 'saying': 10, 'attitude': 2, 'stated': 1, 'drinkingi': 1, 'want': 57, 'believe': 26, 'feeling': 14, 'take': 7, 'small': 1, 'claims': 2, 'court': 1, 'fiance': 3, 'close': 3, 'mother': 16, 'uncomfortable': 2, 'situation': 9, 'offending': 1, 'known': 2, 'hold': 2, 'grudges': 1, 'her': 111, 'side': 3, 'before': 9, 'marry': 1, 'son': 4, 'hav': 1, 'had': 23, 'suicidal': 4, 'thouts': 1, 'your': 3, 'advice': 3, 'bigger': 1, 'nothing': 8, 'regular': 1, 'basis': 2, 'example': 6, 'got': 9, 'call': 3, 'died': 2, 'cry': 13, 'parents': 16, 'anyone': 12, 'help': 15, 'afraid': 14, 'being': 27, 'laughed': 1, 'observe': 1, 'everyone’s': 1, 'actions': 6, 'relationships': 4, 'reasoning': 1, 'lack': 3, 'better': 7, 'term': 1, 'retarded': 1, 'friend': 8, 'answer': 2, 'immediately': 1, 'ignoring': 2, 'go': 13, 'downward': 1, 'spiral': 1, 'until': 4, 'hear': 7, 'from': 20, 'them': 39, 'sure': 8, 'disorder': 5, 'some': 8, 'sort…': 1, 'lies': 1, 'constantly': 9, 'tells': 1, 'same': 8, 'story': 1, '3': 2, 'during': 5, 'week': 7, 'its': 5, 'changing…': 1, 'now': 20, 'woman': 3, 'last': 8, 'while': 5, 'calm': 2, 'took': 5, 'blame': 3, 'everything…admitted': 1, 'was': 68, 'wrong': 12, 'etc': 7, 'cut': 3, 'off…': 1, 'man': 2, 'picture': 2, 'coaching': 1, 'set': 2, 'started': 9, 'study': 1, 'keep': 6, 'asking': 5, 'why': 10, 'not': 74, 'studying': 2, 'medicine': 1, 'sorry': 1, 'can': 24, 'change': 5, 'major': 2, 'dentistry': 2, 'attending': 1, 'anyway': 2, 'it’s': 13, 'higher': 1, 'than': 9, 'current': 2, 'just': 60, 'throw': 1, 'off': 11, 'people’s': 3, 'do': 42, 'practical': 1, 'offered': 1, 'lose': 2, 'semester': 1, 'late': 3, '!': 4, 'college': 3, 'focused': 2, 'girl': 5, 'others': 11, 'may': 11, 'seem': 25, 'only':  ...
# Distortion 'All-or-nothing thinking':
# {'but': 66, 'recently': 3, 'i': 488, 'started': 9, 'thinking': 10, 'about': 24, 'it': 65, 'more': 12, 'and': 212, 'realized': 3, 'those': 4, 'vague': 1, 'memories': 1, 'were': 5, 'kind': 4, 'of': 76, 'all': 35, 'had': 26, 'now': 20, '.': 308, 'why': 6, 'can': 16, 'she': 25, 'look': 2, 'like': 49, 'that': 59, 'have': 66, 'to': 186, 'work': 4, 'keep': 6, 'myself': 27, 'healthy': 3, '?': 15, 'are': 19, 'such': 3, 'high': 6, 'expectations': 1, 'put': 3, 'on': 33, 'me': 82, 'doesn’t': 7, 'live': 6, 'up': 22, 'is': 57, 'my': 125, 'biggest': 1, 'role': 1, 'model': 1, ',': 205, 'think': 16, 'at': 25, 'this': 40, 'moment': 3, 'starving': 1, 'until': 9, 'her': 17, 'when': 32, 'she’s': 2, 'not…my': 1, 'motivation': 2, 'goes': 4, 'away': 5, 'want': 35, 'restrict': 1, 'sometimes': 14, 'can’t': 19, 'help': 10, 'what': 21, 'say': 11, 'parents': 7, 'if': 34, 'they’re': 2, 'in': 67, 'face': 2, 'yelling': 2, 'just': 33, 'said': 2, 'or': 51, 'how': 10, 'forgot': 1, 'do': 37, 'something': 13, 'not': 24, 'yell': 2, 'back': 17, 'its': 4, 'disrespect': 1, 'feel': 57, 'they': 20, 'no': 16, 'respect': 1, 'for': 52, 'avoid': 3, 'these': 9, 'confrontations': 1, 'the': 134, 'only': 8, 'way': 10, 'completely': 8, 'ignore': 1, 'whole': 8, 'family': 12, 'i’ve': 16, 'been': 16, 'doing': 9, 'by': 8, 'sleeping': 5, 'day': 11, 'schoolwork': 1, 'suffering': 3, 'also': 5, 'barely': 1, 'eat': 3, 'because': 30, 'arguments': 1, 'always': 19, 'seem': 3, 'find': 7, 'their': 5, 'into': 14, 'life': 20, 'then': 22, 'decided': 1, 'become': 7, 'vegetarian': 1, 'anorexic': 1, 'tell': 6, 'you': 8, 'truth': 2, 'wasn’t': 4, 'a': 120, 'complete': 2, 'vegan': 1, 'first': 10, 'was': 44, '“': 10, '98%': 1, 'vege': 2, '”': 10, 'meaning': 1, 'ate': 1, 'hotdogs/hamburgers/chicken': 1, 'nuggets/bacon/top': 1, 'ramen': 1, 'soup': 1, 'seventh': 1, 'grade': 2, 'became': 2, 'full-fledged': 1, 'continued': 1, 'problems': 2, 'eighth': 1, 'turned': 4, 'around': 5, 'food': 3, 'nazi': 1, ':': 2, 'additives': 1, 'meat': 1, 'as': 22, 'be': 32, 'there': 8, 'times': 7, 'where': 7, 'figured': 3, 'should': 4, 'even': 22, 'nothing': 12, 'ever': 8, 'good': 11, 'enough': 6, 'mostly': 1, 'failure': 4, 'thought': 8, 'won': 1, 'seemingly': 1, 'endless': 1, 'battle': 1, 'against': 1, 'ocd': 2, 'triumphing': 1, 'over': 10, 'eating': 1, 'disorder': 1, 'anorexia': 1, 'specific': 1, 'common': 3, 'symptoms': 1, 'checking': 1, 'switches': 1, 'countless': 1, 'washing': 1, 'hands': 3, 'forever': 3, 'hoarding': 1, 'gotten': 1, 'hold': 1, 'rampaging': 1, 'thoughts': 3, 'severe': 1, 'panic': 1, 'attack': 1, 'few': 8, 'days': 8, 'ago': 6, 'outside': 2, 'world': 8, 'we': 17, 'perfect': 3, 'couple': 2, 'who': 11, 'loves': 1, 'adventure': 1, 'travel': 1, 'cooking': 1, 'madly': 1, 'love': 12, 'behind': 1, 'door': 1, 'different': 3, 'story': 2, 'half': 3, 'reason': 4, 'am': 41, 'really': 23, 'close': 5, 'friends': 12, 'hang': 2, 'out': 19, 'with': 42, 'etc': 4, 'while': 3, 'everybody': 1, 'usually': 4, 'going': 7, 'movies': 2, 'beach': 1, 'somewhere': 1, 'fun': 2, 'i’m': 41, 'home': 4, 'mother': 7, 'has': 15, 'notice': 1, 'suggests': 1, 'hangout': 1, 'don’t': 39, 'heart': 2, 'any': 10, 'saying': 1, 'die': 3, 'leave': 4, 'everyday': 5, 'come': 2, 'from': 16, 'school': 8, 'house': 3, 'argue': 1, 'every': 6, 'little': 4, 'thing': 6, 'mom': 2, 'mean': 6, 'bursting': 1, 'tears': 2, 'dont': 10, 'im': 11, 'arguing': 1, 'so': 21, 'hard': 9, 'take': 2, 'things': 20, 'get': 28, 'depressed': 7, 'show': 4, 'emotions': 6, 'after': 9, 'looking': 2, 'almost': 3, '3': 1, 'years': 13, 'reluctant': 1, 'effort': 1, 'fruitless': 1, 'action': 1, 'same': 6, 'pursuing': 1, 'relationship': 6, 'goals': 1, 'dreams': 3, 'plans': 1, 'future': 4, 'honestly': 1, 'walk': 1, 'clothes': 1, 'embrace': 1, 'fact': 2, 'shouldn’t': 2, 'run': 1, 'fate': 1, 'dying': 2, 'street': 2, 'divorced': 1, '11': 1, 'know': 22, 'since': 11, 'longer': 2, 'lonely': 3, 'confused': 1, 'miserable': 3, 'desparately': 1, 'trying': 7, 'i”ve': 1, 'lived': 1, 'houston': 1, '16': 2,  ...
# Distortion 'Overgeneralization':
# {'i': 590, 'feel': 68, 'like': 56, 'he': 79, 'has': 41, 'split': 2, 'personalities': 1, '.': 455, 'many': 10, 'times': 10, 'doesn’t': 14, 'remember': 5, 'tasks': 1, 'completed': 1, 'days': 2, 'ago': 6, 'we': 22, 'are': 28, 'at': 44, 'a': 141, 'stressful': 3, 'time': 40, 'in': 92, 'our': 6, 'relationship': 12, 'which': 13, 'includes': 2, 'the': 185, '6': 6, 'month': 2, 'old': 5, 'baby': 3, 'used': 9, 'to': 263, 'be': 47, 'best': 6, 'friends': 17, 'and': 314, 'still': 5, 'today': 2, 'sometimes': 9, 'enjoy': 4, 'shared': 1, 'with': 86, ',': 303, 'but': 76, 'see': 6, 'more': 14, 'no': 41, 'idea': 3, 'of': 135, 'what': 23, 'i’m': 61, 'referring': 1, 'because': 40, 'asks': 1, '“': 7, 'huh': 1, '?': 12, '”': 7, 'all': 55, 'there': 21, 'been': 50, 'lingering': 1, 'problems': 10, 'really': 28, 'don’t': 34, 'understand': 5, 'any': 25, 'this': 47, 'falling': 2, 'deeply': 1, 'into': 9, 'depression': 7, 'myself': 29, 'that': 123, 'along': 6, 'weight': 3, 'can’t': 23, 'shed': 1, 'if': 39, 'ask': 8, 'him': 28, 'for': 101, 'truth': 2, 'will': 18, 'simply': 3, 'look': 3, 'me': 162, 'face': 2, 'tell': 7, 'another': 6, 'lie': 7, '{i': 1, 'bear': 2, 'it': 91, 'seriously.}': 1, 'was': 71, 'very': 29, 'difficult': 4, 'child': 5, 'raise': 1, 'constant': 4, 'fighting': 4, 'between': 4, 'my': 232, 'parents': 15, 'couldn’t': 2, 'talk': 15, 'anyone': 13, 'had': 38, 'trust': 10, 'adults': 1, 'same': 11, 'goes': 4, 'life': 34, '–': 6, 'just': 34, 'seem': 14, 'get': 28, 'anything': 35, 'started': 11, ':': 3, 'job': 7, 'applications': 1, 'writing': 1, 'routines': 1, 'relationships': 6, 'opposite': 2, 'sex': 3, 'you': 4, 'name': 2, 'brother': 7, 'always': 63, 'gets': 13, 'everything': 31, 'sees': 1, 'dad': 9, '£30': 1, 'or': 67, 'every': 17, 'money': 4, 'stuff': 4, 'as': 44, 'well': 6, 'everyday': 10, 'when': 36, 'go': 16, 'is': 89, '£5': 1, 'also': 16, 'got': 8, 'xbox': 2, 'connect': 2, 'asked': 1, '360': 1, 'said': 5, 'comes': 2, 'home': 7, 'brags': 1, 'about': 58, 'getting': 7, 'fed': 1, 'up': 28, 'birthday': 1, 'little': 9, 'ornament': 1, 'want': 17, 'ungrateful': 1, 'its': 7, 'treats': 1, 'different': 8, 'should': 5, 'treat': 1, 'us': 9, 'both': 4, 'think': 19, 'favouritism': 1, 'have': 128, 'grown': 1, 'much': 14, 'not': 49, 'deal': 2, 'issues': 11, 'immature': 1, 'never': 55, 'accepts': 2, 'responsibility': 2, 'his': 13, 'part': 5, 'problem': 10, 'fault': 4, 'according': 1, 'try': 10, 'resolve': 1, 'an': 12, 'issue': 4, 'she': 53, 'blows': 1, 'uses': 2, 'f-word': 1, 'tells': 1, 'care': 6, 'room': 4, 'talking': 2, 'screaming': 1, 'here': 6, 'perfect': 1, 'own': 8, 'mistakes': 1, 'apologize': 2, 'medication': 1, 'resistant': 1, 'tried': 9, 'them': 23, 'medications': 2, 'out': 31, 'bipolari': 1, 'know': 26, 'how': 22, 'find': 5, 'dr': 1, 'am': 52, 'afraid': 7, 'cognitive': 1, 'loss': 4, 'memory': 5, 'nothing': 14, 'on': 45, 'regular': 1, 'basis': 3, 'example': 5, 'call': 3, 'saying': 2, 'mother': 11, 'died': 3, 'would': 19, 'even': 25, 'cry': 1, 'help': 9, 'being': 17, 'laughed': 1, 'observe': 1, 'everyone’s': 1, 'actions': 2, 'reasoning': 1, 'everyone': 9, 'lack': 13, 'better': 8, 'term': 2, 'retarded': 1, 'friend': 10, 'they': 30, 'answer': 2, 'immediately': 2, 'ignoring': 1, 'downward': 1, 'spiral': 1, 'until': 2, 'hear': 3, 'back': 11, 'from': 37, 'last': 7, 'year': 6, 'stupid': 2, 'mistake': 1, 'made': 8, 'huge': 1, 'some': 14, 'rest': 5, 'betrayed': 1, 'fight': 4, 'almost': 9, 'gave': 2, 'love': 14, 'support': 2, 'needed': 2, 'point': 12, 'where': 8, 'show': 1, 'loves': 3, 'appreciates': 1, 'boyfriend': 11, 'already': 1, 'do': 47, 'girlfriend': 2, 'takking': 1, 'anti-depressants': 1, 'helped': 2, 'only': 12, 'few': 7, 'exams': 1, 'left': 5, 'then': 10, 'master’s': 1, 'thesis': 1, 'escape': 1, 'fantasy': 1, 'sf': 1, 'films': 1, 'novels-': 1, 'thing': 12, 'shuts': 1, 'world': 2, 'dated': 1, 'man': 3, 'who': 12, 'didn’t': 9, 'cheat': 1, 'something': 11, 'else': 5, 'bad': 15, 'guess': 2, 'i’ve': 38, 'hurt': 5, 'so': 30, 'badly': 1, 'taking': 1, 'fair': ...
# Distortion 'Mental filter':
# {'i': 489, 'am': 39, 'highly': 1, 'disorganized': 1, ',': 284, 'i’m': 59, 'concerned': 1, 'with': 54, 'being': 15, 'diagnosed': 2, 'schizophrenia': 3, 'or': 55, 'something': 16, 'like': 66, 'that': 79, 'everything': 19, 'was': 31, 'perfect': 3, 'and': 251, 'trusted': 2, 'him': 17, 'whole-heartedly': 1, '.': 321, 'up': 17, 'until': 4, 'recently': 4, 'i’ve': 25, 'been': 27, 'very': 20, 'suspicious': 2, 'my': 176, 'trust': 5, 'just': 29, 'keeps': 7, 'going': 14, 'down': 6, 'started': 7, 'to': 188, 'lose': 2, 'when': 30, 'finding': 3, 'a': 117, 'text': 1, 'message': 1, 'in': 62, 'his': 9, 'phone': 5, 'from': 24, 'someone': 5, 'calling': 1, '“': 10, 'babe': 1, '”': 9, 'on': 29, 'valentines': 1, 'day': 19, 'he': 37, 'said': 4, 'it': 83, 'nothing': 11, 'asked': 2, 'see': 13, 'the': 134, 'rest': 1, 'of': 97, 'messages': 1, 'person': 6, 'but': 66, 'no': 25, 'because': 28, 'thought': 12, 'would': 9, 'change': 4, 'dynamics': 1, 'our': 7, 'relationship': 10, 'supposed': 1, 'so': 24, 'let': 5, 'go': 21, 'ever': 8, 'since': 14, 'occasion': 1, 'it’s': 17, 'hard': 11, 'for': 38, 'me': 99, 'did': 2, 'beginning': 1, 'almost': 7, 'feel': 74, 'convincing': 1, 'myself': 29, 'have': 91, 'this': 33, 'feeling': 12, 'inside': 4, 'should': 2, 'end': 4, 'before': 6, 'get': 32, 'hurt': 2, 'wait': 1, 'out': 21, 'if': 18, 'can': 21, 'really': 29, 'become': 4, 'as': 27, 'good': 4, 'could': 6, '?': 5, 'year': 11, 'not': 33, 'takking': 1, 'any': 15, 'anti-depressants': 2, 'they': 18, 'never': 19, 'helped': 2, 'only': 16, 'few': 4, 'exams': 1, 'left': 3, 'then': 7, 'master’s': 1, 'thesis': 1, 'can’t': 28, 'do': 25, 'anything': 13, 'escape': 2, 'into': 9, 'fantasy': 1, 'sf': 1, 'films': 1, 'novels-': 1, 'thing': 12, 'shuts': 1, 'world': 6, 'some': 10, 'time': 37, 'parents': 6, 'refuse': 1, 'too': 6, 'believe': 5, 'is': 63, 'wrong': 8, 'every': 16, 'scream': 1, 'at': 23, 'break': 2, 'things': 33, 'well': 5, 'insult': 1, 'about': 49, 'how': 16, 'useless': 2, 'always': 20, 'ruining': 1, 'their': 2, 'lives': 3, '!': 3, 'friends': 13, 'all': 36, 'say': 6, 'amazing': 4, 'such': 5, 'friend': 3, 'believing': 1, 'them': 20, 'own': 2, 'seem': 6, 'hate': 11, 'sad': 2, 'clinically': 1, 'depressed': 11, 'rode': 1, 'bike': 2, 'car': 1, 'hit': 4, 'july': 1, 'knee': 1, 'got': 3, 'infected': 1, 'still': 19, 'limping': 1, 'lost': 7, 'one': 15, 'makes': 6, 'happy': 8, '–': 3, 'riding': 1, 'dad': 9, 'mom': 9, 'are': 17, 'seperated': 1, 'barely': 3, 'sometimes': 11, 'will': 17, 'call': 1, 'promise': 1, 'take': 5, 'somewhere': 4, 'gift': 1, 'wanted': 2, 'more': 18, 'lately': 5, 'has': 12, 'breaking': 1, 'promises': 1, 'help': 5, 'cry': 5, 'broken': 2, 'many': 8, 'tired': 1, 'crying': 5, 'expect': 1, 'now': 23, 'don’t': 46, 'want': 15, 'over': 14, 'anymore': 8, 'gained': 1, 'back': 7, 'weight': 7, 'had': 25, 'during': 5, 'interferon': 1, 'therapy': 3, 'alone': 6, 'life': 25, 'know': 23, 'what': 17, 'work': 3, 'there': 9, 'wife': 1, 'along': 1, 'emotional': 4, 'closeness': 1, 'between': 1, 'us': 2, 'she': 30, 'goes': 1, 'weekends': 1, 'her': 21, 'girlfriends': 1, 'stay': 2, 'home': 5, 'close': 4, 'lack': 2, 'confidence': 1, 'excites': 1, 'look': 4, 'forward': 1, 'even': 30, 'meet': 2, 'new': 4, 'people': 27, 'where': 11, 'start': 7, 'girlfriend': 4, 'mainly': 2, 'cause': 3, 'needs': 2, 'be': 15, 'done': 7, 'bc': 2, 'holding': 1, 'says': 5, 'think': 31, 'everyday': 5, 'live': 8, 'pro': 1, 'licence': 1, 'drive': 3, 'most': 3, 'days': 8, 'worse': 6, 'that’s': 4, 'possible': 1, 'won’t': 5, 'kill': 6, 'sister': 4, 'laws': 1, 'belly': 2, 'once': 3, 'mine': 2, 'literally': 5, 'cried': 2, 'touched': 1, 'asks': 1, 'baby': 2, 'doing': 4, 'instantly': 2, 'regretted': 1, 'couldn’t': 4, 'regret': 1, 'spiraling': 2, 'state': 6, 'despair': 1, 'cannot': 5, 'enjoy': 5, 'around': 15, 'birds': 1, 'trees': 1, 'sky': 1, 'smile': 1, 'brings': 2, 'joy': 3, 'bothers': 2, 'sensitive': 3, 'effects': 2, 'than': 8, 'anyone': 6, 'else': 1, 'tormenting': 1, 'figure': 4, '16': 2, 'worst': 5, 'somehow': 3, 'towards' ...
# Distortion 'Should statements':
# {'in': 48, 'the': 111, 'past': 7, 'few': 4, 'years': 6, ',': 218, 'i': 454, 'haven’t': 4, 'been': 17, 'getting': 2, 'much': 8, 'out': 12, 'of': 69, 'life': 11, '.': 238, 'don’t': 27, 'feel': 60, 'anything': 11, 'like': 40, 'used': 4, 'to': 211, 'anger': 6, 'happiness': 1, 'joy': 1, 'and': 189, 'even': 28, 'sadness': 1, 'seem': 7, 'have': 75, 'left': 2, 'me': 68, 'things': 25, 'that': 82, 'give': 4, 'emotional': 4, 'pleasure': 2, 'now': 16, 'just': 46, 'entertain': 1, 'occupy': 1, 'my': 86, 'mind': 4, 'ups': 1, 'downs': 1, 'teenagers': 1, 'are': 20, 'supposed': 10, 'everything': 6, 'seems': 3, 'kind': 5, 'flat': 1, 'with': 45, 'a': 97, 'dips': 1, 'very': 13, '“': 9, 'real': 4, '”': 8, 'anymore': 4, 'world': 2, 'feels': 2, 'dreamy': 1, 'am': 37, 'constantly': 5, 'withdrawn': 1, 'we': 14, 'would': 20, 'fight': 1, 'almost': 4, 'everyday': 1, 'he': 18, 'always': 13, 'lie': 1, 'never': 13, 'gave': 1, 'love': 3, 'support': 3, 'really': 19, 'needed': 3, 'it': 63, 'got': 7, 'point': 7, 'where': 12, 'ask': 3, 'him': 7, 'show': 5, 'loves': 2, 'appreciates': 1, 'all': 23, 'stuff': 2, 'boyfriend': 3, 'should': 34, 'already': 3, 'do': 30, 'for': 40, 'his': 6, 'girlfriend': 1, 'before': 9, 'started': 5, 'dating': 3, 'first': 3, 'year': 7, 'our': 3, 'relationship': 5, 'her': 17, 'sex': 5, 'drive': 1, 'was': 27, 'amazing': 2, 'over': 12, 'time': 11, 'slowly': 1, 'decreased': 1, 'is': 50, '1-2': 1, 'times': 2, 'month': 3, 'suffering': 2, 'from': 16, 'bulimia': 1, 'four': 1, 'months': 5, 'realize': 2, 'health': 1, 'risks': 1, 'know': 54, 'problem': 8, 'trying': 5, 'stop': 6, 'no': 18, 'success': 1, 'this': 41, 'healthy': 3, 'fear': 4, 'hard': 5, 'work': 8, 'completed': 2, 'be': 62, 'person': 13, 'going': 7, 'down': 2, 'drain': 1, 'some': 6, 'self': 2, 'esteem': 2, 'issues': 3, 'will': 12, 'continue': 1, 'on': 19, 'but': 71, 'you': 8, 'any': 10, 'advice': 1, 'or': 34, 'tricks': 1, 'these': 10, 'behaviors': 1, 'seemed': 1, 'become': 3, 'habitual': 1, 'uncontrollable': 1, 'dealt': 1, 'problems': 7, 'shot': 1, 'extremely': 4, 'anxious': 4, 'when': 32, 'doing': 6, 'tasks': 1, 'small': 3, 'ones': 1, 'packing/unpacking': 1, 'suitcase': 1, 'then': 7, 'push': 1, 'aside': 1, 'get': 21, 'nothing': 6, 'done': 2, 'habits': 1, 'cleanliness': 1, 'such': 4, 'as': 16, 'apartment': 1, 'declined': 1, 'because': 24, 'refuse': 1, 'motivate': 1, 'myself': 30, 'clean': 1, 'i’ll': 1, 'find': 11, 'kitchen': 1, 'bedroom': 1, 'reason': 6, 'randomly': 1, 'bathroom': 1, 'ultimately': 1, 'accomplishing': 1, 'also': 10, 'pressured': 1, 'what': 21, 'finish': 2, 'masters': 1, 'i’m': 45, 'too': 10, 'lackadaisical': 1, 'search': 2, 'jobs': 2, 'struggling': 1, 'at': 23, 'moment': 2, 'yet': 4, 'aware': 2, 'feeling': 4, 'good': 7, 'most': 9, 'people': 17, 'age': 3, 'worry': 6, 'about': 23, 'their': 4, 'bills': 1, 'retirement': 1, 'so': 20, 'she': 9, 'only': 11, 'concerned': 1, 'makeup': 1, 'hair': 1, 'music': 2, 'friends': 10, 'gullible': 1, 'it’s': 26, 'relatively': 1, 'long': 4, 'im': 4, 'better': 9, 'cant': 5, 'bad': 8, 'thing': 9, 'cannot': 4, 'express': 1, 'open': 1, 'bpdy': 1, 'can’t': 19, 'they': 8, 'feel…': 1, 'word': 1, 'not': 40, 'caring': 2, 'bit': 1, 'strong': 3, 'care': 10, 'degree': 1, 'enough': 4, 'which': 5, 'one': 10, 'way': 18, 'can': 14, 'put': 2, 'usually': 1, 'happens': 2, 'wake': 1, 'up': 12, 'thinking': 8, 'think': 19, 'necessarily': 1, 'negative': 3, 'shifts': 1, 'another': 5, 'morning': 1, '13': 1, 'if': 23, 'weird': 4, 'turn': 4, 'off': 5, 'apathy': 2, 'levels': 1, '?': 9, 'act': 4, 'how': 13, 'during': 3, 'certain': 2, 'situations': 1, 'raising': 1, 'empathy/decreasing': 1, 'want': 27, 'number': 1, 'understand': 4, 'family': 10, 'shouldn’t': 14, 'involved': 1, 'your': 2, 'friend': 2, 'group': 1, 'etc': 2, 'keeping': 1, 'attend': 1, 'best': 3, 'schools': 1, 'country': 1, 'excellent': 1, 'living': 1, 'conditions': 1, 'everybody': 2, 'who': 7, 'lives': 1, 'house': 1, 'has': 4, 'need': 10, 'way…': 1, 'still': 3, 'other': 12, 'members': 1, 'great': 5, 'amount': ...

# %%
# Displaying the results of word (token) frequency for each cognitive distortion

# Display graphs for each distortion
for distortion, tokens_dict in distortions_dicts.items():
    plot_dict(
        tokens_dict,
        labels="word",
        values="count",
        title=f"Distortion: {distortion}",
        head=20             # Top 20 words
    )


# Display a general graph for all tokens
plot_dict(
    all_tokens_dict,
    labels="word",
    values="count",
    title="All tokens",
    head=20                # Top 20 words
)

# %% [markdown]
# ## Define working functions to be moved to the code module

# %%
# Analyze the frequency of n-grams for each cognitive distortion

from pygents.aigents_api import build_ngrams

def count_ngrams_basic(path: str, n_max: int):

    df = pd.read_csv(path)
    df = df.drop('Id_Number', axis=1) # delete columnb with id 
    
    distortions = defaultdict(int)

    # Creating dictionaries for counting n-grams
    n_gram_dicts = defaultdict(lambda: defaultdict(int))  # A dictionary for each distortion (distortion-n-gram-n_gram_frequency)
    all_n_grams = defaultdict(int)  # A general dictionary for all n-grams
    
    uniq_n_gram_dicts = defaultdict(lambda: defaultdict(int)) # Counts of uniq N-grams by Distortion
    n_gram_distortions = defaultdict(lambda: defaultdict(int)) # Counts of distortiions by N-gram

    # Loop through the rows of the DataFrame
    for _, row in df.iterrows():
        # Text identification: first, check the 2nd column; if NaN, take the text from the 1st column
        text = row.iloc[1] if pd.notna(row.iloc[1]) else row.iloc[0]
        primary_distortion = row.iloc[2]  # The primary cognitive distortion from the 3rd column
        secondary_distortion = row.iloc[3] if pd.notna(row.iloc[3]) else None  # The secondary distortion from the 4th column, if present

        dictcount(distortions,primary_distortion)
        if secondary_distortion:
            dictcount(distortions,secondary_distortion)
        
        # Text tokenization
        tokens = tokenize_re(text)

        # Generation and counting of n-grams (from 1 to 4)
        for n in range(1, n_max + 1):
            n_grams = build_ngrams(tokens, n)
            dictcount(all_n_grams, n_grams)
            dictcount(n_gram_dicts[primary_distortion], n_grams)  # Increment the counter for the corresponding primary distortion
            if secondary_distortion:
                dictcount(n_gram_dicts[secondary_distortion], n_grams) # Increment the counter for the corresponding secondary distortion (if present)

            uniq_n_grams = set(n_grams)
            for uniq_n_gram in uniq_n_grams:
                dictcount(uniq_n_gram_dicts[primary_distortion], uniq_n_gram)
                dictcount(n_gram_distortions[uniq_n_gram],primary_distortion)
                if secondary_distortion:
                    dictcount(uniq_n_gram_dicts[secondary_distortion], uniq_n_gram)
                    dictcount(n_gram_distortions[uniq_n_gram],secondary_distortion)
                
    # Normalizing distortion-specific counts by total counts
    norm_n_gram_dicts = {}
    for n_gram_dict in n_gram_dicts:
        norm_n_gram_dict = {}
        norm_n_gram_dicts[n_gram_dict] = norm_n_gram_dict
        dic = n_gram_dicts[n_gram_dict]
        for n_gram in dic:
            #print(dic[n_gram])
            #print(all_n_grams[n_gram])
            #break
            if len(n_gram) <= n_max:
                norm_n_gram_dict[n_gram] = float( dic[n_gram] ) / all_n_grams[n_gram]

    # Normalize uniq counts 
    norm_uniq_n_gram_dicts = {}
    for uniq_n_gram_dict in uniq_n_gram_dicts:
        norm_uniq_n_gram_dict = {}
        norm_uniq_n_gram_dicts[uniq_n_gram_dict] = norm_uniq_n_gram_dict
        dic = uniq_n_gram_dicts[uniq_n_gram_dict]
        nonuniq_dic = n_gram_dicts[n_gram_dict]
        # Normalize uniq Document counts of N-grams by distortion by Documents count by Distortion
        for n_gram in dic:
            if len(n_gram) <= n_max:
                #norm_uniq_n_gram_dict[n_gram] = float( dic[n_gram] ) * nonuniq_dic[n_gram] / distortions[uniq_n_gram_dict] / len(n_gram_distortions[n_gram]) / all_n_grams[n_gram]
                norm_uniq_n_gram_dict[n_gram] = float( dic[n_gram] ) / distortions[uniq_n_gram_dict] / len(n_gram_distortions[n_gram])
                
    return distortions, n_gram_dicts, all_n_grams, norm_n_gram_dicts, uniq_n_gram_dicts, n_gram_distortions, norm_uniq_n_gram_dicts

# %% [markdown]
# ## Test on synthetic data

# %%
def plot_debug_charts(distortions, n_gram_dicts, all_n_grams, norm_n_gram_dicts, n_top):
    # Display graphs for all distortions
    plot_dict(
            distortions,
            labels="Distortion",
            values="count",
            title=f"All distortions",
            head=n_top             # All
        )
    # Display graphs for each distortion
    plot_dict(
            all_n_grams,
            labels="word",
            values="count",
            title=f"All",
            head=n_top             # All
        )
    for distortion, ngram_dict in n_gram_dicts.items():
        plot_dict(
            ngram_dict,
            labels="word",
            values="count",
            title=f"Distortion: {distortion}",
            head=n_top             # Top 20 n-grams
        )
    # Display graphs for each distortion
    for distortion, ngram_dict in norm_n_gram_dicts.items():
        plot_dict(
            ngram_dict,
            labels="word",
            values="count",
            title=f"Normalized Distortion: {distortion}",
            head=n_top             # Top 20 n-grams
        )

# %%
distortions, n_gram_dicts, all_n_grams, norm_n_gram_dicts, uniq_n_gram_dicts, n_gram_distortions, norm_uniq_n_gram_dicts \
= count_ngrams_basic("./data/corpora/English/distortions/sagarikashreevastava/test.csv",2)
plot_debug_charts(distortions, n_gram_dicts, all_n_grams, norm_n_gram_dicts, 20)

# %%
   for distortion, ngram_dict in norm_uniq_n_gram_dicts.items():
        plot_dict(
            ngram_dict,
            labels="word",
            values="count",
            title=f"Normalized Uniq counts for Distortion: {distortion}",
            head=20             # Top 20 n-grams
        )

# %%
distortions, n_gram_dicts, all_n_grams, norm_n_gram_dicts, uniq_n_gram_dicts, n_gram_distortions, norm_uniq_n_gram_dicts \
= count_ngrams_basic(sagar_path+"/Annotated_data.csv",1)
#plot_debug_charts(distortions, n_gram_dicts, all_n_grams, norm_n_gram_dicts, 20)

# %%
# Display graphs for all distortions
plot_dict(
            distortions,
            labels="Distortion",
            values="count",
            title=f"All distortions",
            head=20             # All
        )
    
for distortion, ngram_dict in uniq_n_gram_dicts.items():
        plot_dict(
            ngram_dict,
            labels="word",
            values="count",
            title=f"Raw Uniq counts for Distortion: {distortion}",
            head=20             # Top 20 n-grams
        )

for distortion, ngram_dict in norm_uniq_n_gram_dicts.items():
        plot_dict(
            ngram_dict,
            labels="word",
            values="count",
            title=f"Normalized Uniq counts for Distortion: {distortion}",
            head=20             # Top 20 n-grams
        )

# %%
n_gram_distortions[('i',)]
# Out:
# defaultdict(int,
#             {'Labeling': 160,
#              'Emotional Reasoning': 158,
#              'No Distortion': 872,
#              'Fortune-telling': 186,
#              'Magnification': 218,
#              'Mind Reading': 242,
#              'Personalization': 187,
#              'All-or-nothing thinking': 117,
#              'Overgeneralization': 209,
#              'Mental filter': 134,
#              'Should statements': 128})

# %%
len(n_gram_distortions[('i',)])
# Out:
# 11
