# %%
import os, sys
cwd = os.getcwd()
project_path = cwd[:cwd.find('pygents')+7]
if project_path not in sys.path: sys.path.append(project_path)
os.chdir(project_path) 

#https://stackoverflow.com/questions/41827983/right-way-to-calculate-the-cosine-similarity-of-two-word-frequency-dictionaries
#https://realpython.com/python-counter/

#from scipy.spatial.distance import cosine
#from sklearn.metrics.pairwise import cosine_similarity

import gc
from copy import deepcopy as dcp
import pandas as pd

#force reimport
if 'pygents.util' in sys.modules:
    del sys.modules['pygents.util']
if 'pygents.text' in sys.modules:
    del sys.modules['pygents.text']
if 'pygents.plot' in sys.modules:
    del sys.modules['pygents.plot']
if 'pygents.token' in sys.modules:
    del sys.modules['pygents.token']
if 'pygents.cluster' in sys.modules:
    del sys.modules['pygents.cluster']

from pygents.token import *
from pygents.text import *
from pygents.util import *
from pygents.cluster import *
from pygents.plot import plot_bars, plot_dict, matrix_plot, igraph_draw, dict2tree, dict2graph

# %%
base = FreedomTokenizer(name='data/models/brown_nolines_chars_7a',max_n=7,mode='chars',debug=False)
dicastree = {}
do_cluster(base.model,dic4tree=dicastree,debug=False)
dict2tree(dicastree).show()
# Out:
# └──  !"#$%&'()*+,-./0123456789:;<>?@[\]^_`abcdefghijklmnopqrstuvwxyz{|}~
#     ├──  !"#$%&'()*+,-./0123456789:;<>?@[]^_`abcdefghijklmnopqrstuvwxyz{}~
#     │   ├──  !"#$%&'()+,-./0123456789:;<>?@[]^_`abcdefghijklmnopqrstuvwxyz{}~
#     │   │   ├──  !"#$%&'()+,-./0123456789:;<>?@[]^_`abcdefghijklmnoprstuvwxyz{}~
#     │   │   │   ├──  !"#$&'()+,-.1:;<>?@[]^_abcdefghijklmnoprstuvwxyz{}~
#     │   │   │   │   ├──  !"#$&()+,-.1:;<>?@[]^_abcdefghijklmnoprstuvwxyz{}~
#     │   │   │   │   │   ├──  !"#$&()+,-.1:;<>?@[]^_abcdefgijklmnoprstuvwxyz{}~
#     │   │   │   │   │   │   ├──  x
#     │   │   │   │   │   │   │   ├──
#     │   │   │   │   │   │   │   └── x
#     │   │   │   │   │   │   └── !"#$&()+,-.1:;<>?@[]^_abcdefgijklmnoprstuvwyz{}~
#     │   │   │   │   │   │       ├── !"#$&()+,-.1:;<>?@[]_bcdfgjklmnprstvwyz{}~
#     │   │   │   │   │   │       │   ├── !#&)+,-.:;>?@]_dgklnrsvyz}
#     │   │   │   │   │   │       │   │   ├── !#&)+,-.:;>?@]_dgsy}
# ...

# %%
nodes, edges = dict2graph(dicastree)
igraph_draw(nodes,edges,'English Brown')
# Out:
# <div>                            <div id="722b3ae6-8175-4388-ba58-795237aaef71" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("722b3ae6-8175-4388-ba58-795237aaef71")) {                    Plotly.newPlot(                        "722b3ae6-8175-4388-ba58-795237aaef71",                        [{"hoverinfo":"none","line":{"color":"rgb(210,210,210)","width":1},"mode":"lines","x":[-15.208333333333334,-14.708333333333334,null,-14.708333333333334,-14.208333333333334,null,-14.208333333333334,-12.708333333333334,null,-12.708333333333334,-12.208333333333334,null,-12.208333333333334,-11.708333333333334,null,-11.708333333333334,-10.708333333333334,null,-10.708333333333334,-8.708333333333334,null,-8.708333333333334,0.0,null,0.0,0.9166666666666661,null,0.916666666
# ...

# %%
model_compress_with_loss(base.model,0.0001)
dicastree = {}
do_cluster(base.model,dic4tree=dicastree,debug=False)
dict2tree(dicastree).show()
# Out:
# └──  !"#$%&'()*+,-./0123456789:;<>?@[]_abcdefghijklmnopqrstuvwxyz{}~
#     ├──  !"#$%&'()+,-./0123456789:;<>?@[]_abcdefghijklmnopqrstuvwxyz{}~
#     │   ├──  !"#$%&'()+,-./0123456789:;<>?@[]_abcdefghijklmnoprstuvwxyz{}~
#     │   │   ├──  !"#$%&'()+,-.1:;<>?@[]_abcdefghijklmnoprstuvwxyz{}~
#     │   │   │   ├──  !"#$%&()+,-.1:;<>?@[]_abcdefghijklmnoprstuvwxyz{}~
#     │   │   │   │   ├──  !"#$%&()+,-.1:;<>?@[]_abcdefgijklmnoprstuvwxyz{}~
#     │   │   │   │   │   ├──  x
#     │   │   │   │   │   │   ├──
#     │   │   │   │   │   │   └── x
#     │   │   │   │   │   └── !"#$%&()+,-.1:;<>?@[]_abcdefgijklmnoprstuvwyz{}~
#     │   │   │   │   │       ├── !"#$%&()+,-.1:;<>?@[]_bcdfgjklmnprstvwyz{}~
#     │   │   │   │   │       │   ├── !#%&)+,-.:;>?@]_dgklnrsvyz}
#     │   │   │   │   │       │   │   ├── !#%&)+,-.:;>?@]_dgsy}
#     │   │   │   │   │       │   │   │   ├── !#%&)+,-.:;>?@]_dsy}
#     │   │   │   │   │       │   │   │   │   ├── !%&),-.:;>?]dsy}
# ...

# %%
nodes, edges = dict2graph(dicastree)
igraph_draw(nodes,edges,'English Brown 0.0001')
# Out:
# <div>                            <div id="664a8279-608c-47d3-8dd1-b2cea4e09358" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("664a8279-608c-47d3-8dd1-b2cea4e09358")) {                    Plotly.newPlot(                        "664a8279-608c-47d3-8dd1-b2cea4e09358",                        [{"hoverinfo":"none","line":{"color":"rgb(210,210,210)","width":1},"mode":"lines","x":[-13.125,-12.625,null,-12.625,-11.625,null,-11.625,-11.125,null,-11.125,-10.625,null,-10.625,-9.625,null,-9.625,-7.875,null,-7.875,0.0,null,0.0,0.5,null,0.5,-1.875,null,-1.875,-2.375,null,-2.375,-4.125,null,0.0,7.375,null,7.375,6.875,null,-4.125,-5.125,null,-5.125,-5.625,null,-5.625,-6.125,null,-6.125,-6.625,null,-11.625,-10.625,null,-6.625,-7.875,null,-10.625,-11.125,null,6.875,
# ...

# %%
del base
n = gc.collect()

# %%
base = FreedomTokenizer(name='data/models/gutenberg_brown_social_media_chars_7a',max_n=7,mode='chars',debug=False)
do_cluster(base.model,debug=False) # does ugly glyphs...
dict2tree(dicastree).show()

# %%
nodes, edges = dict2graph(dicastree)
igraph_draw(nodes,edges,'Gutenberg Brown Social Media')

# %%
model_compress_with_loss(base.model,0.01)
dicastree = {}
do_cluster(base.model,dic4tree=dicastree,debug=False)
dict2tree(dicastree).show()
# Out:
# └──  *,-./012345:?@_abcdefghijklmnopqrstuvwxyz
#     ├──  *,-./012345:@_abcdefghijklmnopqrstuvwxyz
#     │   ├──  *,-.012345@_abcdefghijklmnopqrstuvwxyz
#     │   │   ├──  ,-.012345@_abcdefghijklmnopqrstuvwxyz
#     │   │   │   ├──  ,-.012345@_abcdefghijklmnoprstuvwxyz
#     │   │   │   │   ├──  ,-.@_abcdefghijklmnoprstuvwxyz
#     │   │   │   │   │   ├──  ,-.@abcdefghijklmnoprstuvwxyz
#     │   │   │   │   │   │   ├──  ,-.abcdefghijklmnoprstuvwxyz
#     │   │   │   │   │   │   │   ├──  ,-.abcdefgijklmnoprstuvwxyz
#     │   │   │   │   │   │   │   │   ├──  ,-.abcdefgijklmnoprstuvwyz
#     │   │   │   │   │   │   │   │   │   ├──  -bcdfgjklmnprstvwyz
#     │   │   │   │   │   │   │   │   │   │   ├──  -bcdfgjklmprstvwyz
#     │   │   │   │   │   │   │   │   │   │   │   ├──
#     │   │   │   │   │   │   │   │   │   │   │   └── -bcdfgjklmprstvwyz
#     │   │   │   │   │   │   │   │   │   │   │       ├── -bcdfgjmpstwy
#     │   │   │   │   │   │   │   │   │   │   │       │   ├── -dgsy
# ...

# %%
nodes, edges = dict2graph(dicastree)
igraph_draw(nodes,edges,'Gutenberg Brown Social Media 0.01')
# Out:
# <div>                            <div id="99985b07-cff0-47ff-99c4-7266706a853a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99985b07-cff0-47ff-99c4-7266706a853a")) {                    Plotly.newPlot(                        "99985b07-cff0-47ff-99c4-7266706a853a",                        [{"hoverinfo":"none","line":{"color":"rgb(210,210,210)","width":1},"mode":"lines","x":[-12.875,-12.125,null,-12.125,-11.625,null,-11.625,-11.125,null,-11.125,-9.25,null,-9.25,-8.75,null,-8.75,-8.25,null,-8.25,-7.75,null,-7.75,-7.25,null,-7.25,-6.0,null,-6.0,0.0,null,0.0,2.5,null,2.5,2.0,null,2.0,-0.125,null,-0.125,-1.875,null,-1.875,-2.375,null,-6.0,-4.75,null,-9.25,-7.375,null,-7.375,-7.875,null,-2.375,-3.375,null,2.0,4.125,null,-0.125,1.625,null,-3.375,-3.875,nu
# ...

# %%
del base
n = gc.collect()

# %%
base = FreedomTokenizer(name='data/models/rusage_test_chars_7a',max_n=7,mode='chars',debug=False)
dicastree = {}
do_cluster(base.model,dic4tree=dicastree,debug=False)
dict2tree(dicastree).show()
# Out:
# ├──
# ]
# │   ├──
#
# │   └── ]
# ├──  -
# │   ├──
# │   └── -
# ├── !),.:;?}©»аеийоуыьюяё…
# │   ├── !),.:;?}©»йьюяё…
# │   │   ├── !),.:;?}©»йюяё…
# │   │   │   ├── !,.:;?}©йюяё…
# │   │   │   │   ├── !,.:;?}©йяё…
# │   │   │   │   │   ├── !,.:;?}©й…
# │   │   │   │   │   │   ├── !,.:;?}©…
# │   │   │   │   │   │   │   ├── !.:?…
# │   │   │   │   │   │   │   │   ├── !?
# │   │   │   │   │   │   │   │   │   ├── !
# │   │   │   │   │   │   │   │   │   └── ?
# │   │   │   │   │   │   │   │   └── .:…
# │   │   │   │   │   │   │   │       ├── .…
# │   │   │   │   │   │   │   │       │   ├── .
# │   │   │   │   │   │   │   │       │   └── …
# │   │   │   │   │   │   │   │       └── :
# │   │   │   │   │   │   │   └── ,;}©
# │   │   │   │   │   │   │       ├── ,;©
# │   │   │   │   │   │   │       │   ├── ,;
# │   │   │   │   │   │   │       │   │   ├── ,
# │   │   │   │   │   │   │       │   │   └── ;
# │   │   │   │   │   │   │       │   └── ©
# │   │   │   │   │   │   │       └── }
# ...

# %%
nodes, edges = dict2graph(dicastree)
igraph_draw(nodes,edges,'RusAge Test/Small')
# Out:
# <div>                            <div id="4a03cac9-a583-4a55-8ec9-d8c124b77ce0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a03cac9-a583-4a55-8ec9-d8c124b77ce0")) {                    Plotly.newPlot(                        "4a03cac9-a583-4a55-8ec9-d8c124b77ce0",                        [{"hoverinfo":"none","line":{"color":"rgb(210,210,210)","width":1},"mode":"lines","x":[-8.014583333333329,-7.264583333333329,null,-26.764583333333324,-26.014583333333324,null,-7.264583333333329,-5.639583333333329,null,-26.014583333333324,-25.514583333333324,null,-25.514583333333324,-21.68124999999999,null,-21.68124999999999,-20.264583333333324,null,-5.639583333333329,-3.5770833333333285,null,-15.264583333333327,-14.764583333333327,null,-20.264583333333324,-20.7645
# ...

# %%
del base
n = gc.collect()

# %%
base = FreedomTokenizer(name='data/models/rusage_chars_7a',max_n=7,mode='chars',debug=False)
dicastree = {}
do_cluster(base.model,dic4tree=dicastree,debug=False)
dict2tree(dicastree).show()
# Out:
# ├──
# ]
# │   ├──
#
# │   └── ]
# ├── !),.:;?\y}©»йюяё”…
# │   ├── !,.:;?\y}©йюяё…
# │   │   ├── !,.:;?y}©йюяё…
# │   │   │   ├── !,.:;?y}©йяё…
# │   │   │   │   ├── !,.:;?}©йяё…
# │   │   │   │   │   ├── !,.:;?}©й…
# │   │   │   │   │   │   ├── !,.:;?}©…
# │   │   │   │   │   │   │   ├── !.:?…
# │   │   │   │   │   │   │   │   ├── !?
# │   │   │   │   │   │   │   │   │   ├── !
# │   │   │   │   │   │   │   │   │   └── ?
# │   │   │   │   │   │   │   │   └── .:…
# │   │   │   │   │   │   │   │       ├── .…
# │   │   │   │   │   │   │   │       │   ├── .
# │   │   │   │   │   │   │   │       │   └── …
# │   │   │   │   │   │   │   │       └── :
# │   │   │   │   │   │   │   └── ,;}©
# │   │   │   │   │   │   │       ├── ,;©
# │   │   │   │   │   │   │       │   ├── ,;
# │   │   │   │   │   │   │       │   │   ├── ,
# │   │   │   │   │   │   │       │   │   └── ;
# │   │   │   │   │   │   │       │   └── ©
# │   │   │   │   │   │   │       └── }
# │   │   │   │   │   │   └── й
# ...

# %%
nodes, edges = dict2graph(dicastree)
igraph_draw(nodes,edges,'RusAge Previews/Full')
# Out:
# <div>                            <div id="5afa9635-53af-461d-87cc-b4da8d534ad0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5afa9635-53af-461d-87cc-b4da8d534ad0")) {                    Plotly.newPlot(                        "5afa9635-53af-461d-87cc-b4da8d534ad0",                        [{"hoverinfo":"none","line":{"color":"rgb(210,210,210)","width":1},"mode":"lines","x":[-47.02291666666666,-46.27291666666666,null,-46.27291666666666,-44.64791666666666,null,-44.64791666666666,-41.231249999999996,null,-38.02291666666666,-37.52291666666666,null,-37.52291666666666,-37.02291666666666,null,-37.02291666666666,-36.52291666666666,null,-36.52291666666666,-33.02291666666666,null,-41.231249999999996,-40.52291666666666,null,-40.52291666666666,-41.022916666666
# ...

# %%
model_compress_with_loss(base.model,0.0001)
dicastree = {}
do_cluster(base.model,dic4tree=dicastree,debug=False)
dict2tree(dicastree).show()
# Out:
# └──
#  !()*,-./0123456789:;=?[]_abcdefghiklmnopqrstuvwxy ©«»абвгдежзийклмнопрстуфхцчшщъыьэюяё–“”…
#     ├──
#  !()*,-./0123456789:;=?[]abcdefghiklmnopqrstuvwxy ©«»абвгдежзийклмнопрстуфхцчшщъыьэюяё–“”…
#     │   ├──
#     │   └──
#  !()*,-./0123456789:;=?[]abcdefghiklmnopqrstuvwxy ©«»абвгдежзийклмнопрстуфхцчшщъыьэюяё–“”…
#     │       ├──
#  !()*,-.0123456789:;=?[]abcdefghiklmnopqrstuvwxy ©«»абвгдежзийклмнопрстуфхцчшщъыьэюяё–“”…
#     │       │   ├──
# ]
#     │       │   │   ├──
# ]
#     │       │   │   │   ├──
#
#     │       │   │   │   └── ]
#     │       │   │   └──
#     │       │   └──  !()*,-.0123456789:;=?[abcdefghiklmnopqrstuvwxy©«»абвгдежзийклмнопрстуфхцчшщъыьэюяё–“”…
#     │       │       ├──  !()*,-.0123456789:;?abcdefghiklmnopqrstuvwxy©«»абвгдежзийклмнопрстуфхцчшщъыьэюяё–“”…
#     │       │       │   ├──  !()*,-.0123456789:;?abcdefghiklmnopqrstuvwxy©«»абвгдежзийклмнопрстуфхцчшщыьэюяё–“”…
# ...

# %%
nodes, edges = dict2graph(dicastree)
igraph_draw(nodes,edges,'RusAge Previews/Full 0.0001')
# Out:
# <div>                            <div id="58e6bf27-e581-42ad-a5db-8871cc9d2e5b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58e6bf27-e581-42ad-a5db-8871cc9d2e5b")) {                    Plotly.newPlot(                        "58e6bf27-e581-42ad-a5db-8871cc9d2e5b",                        [{"hoverinfo":"none","line":{"color":"rgb(210,210,210)","width":1},"mode":"lines","x":[-18.375,-17.875,null,-17.875,-17.375,null,-17.375,-16.375,null,-16.375,-15.125,null,-15.125,-14.625,null,-14.625,-12.375,null,-12.375,-8.875,null,-8.875,0.0,null,0.0,0.375,null,0.0,8.5,null,0.375,-0.125,null,8.5,7.5,null,-0.125,-0.625,null,7.5,7.0,null,-12.375,-10.125,null,7.0,4.875,null,-10.125,-11.125,null,-0.625,-2.375,null,-11.125,-11.625,null,4.875,3.125,null,-2.375,-2.875,
# ...

# %%
del base
n = gc.collect()
